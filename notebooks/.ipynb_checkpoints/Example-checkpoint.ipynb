# %% [markdown]
# # 1. Imports and Setup
# You'll begin by importing necessary libraries, including your GeometricCalibrator library and other standard packages like tensorflow, scikit-learn, or pytorch for the CNN part, and numpy or pandas for data manipulation.

# %%
import sys
import os

# Add the parent directory to the sys.path so Python can find the utils module
sys.path.append(os.path.abspath('..'))

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from utils.metrics import ECE_calc
from calibrators.geometric_calibrators import GeometricCalibrator
from utils.logging_config import *

setup_logging()
# Out:
# 2024-09-24 13:27:24.184795: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-24 13:27:24.206359: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-24 13:27:24.212900: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-24 13:27:28.649477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # 2. Step 1: Data Retrieval
# This part loads your dataset. It could be MNIST, CIFAR-10, or any dataset you're working with. Depending on the experiment, you may switch between different datasets to test the generality of your method.

# %%
from keras.src.datasets.mnist import load_data
from sklearn.model_selection import train_test_split

# Split and save the data for reproducible experiments (to be done once)
# Load MNIST data
(train_X_original, train_y_original), (test_X_original, test_y_original) = load_data()

# Combine train and test data for further splitting
data = np.concatenate((train_X_original, test_X_original), axis=0)
labels = np.concatenate((train_y_original, test_y_original), axis=0)

# Perform the splitting dynamically
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=0)  # 0.25 * 0.8 = 0.2

# %% [markdown]
# # 3. Step 2: Data Augmentation
# Here, you'll apply different augmentation techniques (e.g., rotation, noise addition, or translation). Each augmentation method is treated as a different experiment. You'll want to apply these transformations to the training data before passing them through the model.

# %%
# Ensure the shape is correct by only adding the channel dimension once
# If you already added a channel, avoid calling expand_dims again
if X_train.ndim == 3:  # Check if the array is missing the channel dimension
    X_train = np.expand_dims(X_train, axis=-1)  # Shape becomes (batch_size, 28, 28, 1)
if X_test.ndim == 3:
    X_test = np.expand_dims(X_test, axis=-1)
if X_val.ndim == 3:
    X_val = np.expand_dims(X_val, axis=-1)

# Augmentation methods
def augment_data(images, method='rotation'):
    if method == 'rotation':
        datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=90)
    elif method == 'shift':
        datagen = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1)
    elif method == 'noise':
        noise = np.random.normal(loc=0.0, scale=0.1, size=images.shape)
        return np.clip(images + noise, 0., 1.)
    
    # Ensure images have the correct shape for ImageDataGenerator (rank 4)
    if images.ndim != 4:
        raise ValueError(f"Input to `ImageDataGenerator` should be rank 4. Got shape: {images.shape}")

    datagen.fit(images)
    
    # Use .flow() to create an iterator and retrieve augmented images
    augmented_images = datagen.flow(images, batch_size=len(images), shuffle=False)
    
    # Convert iterator output to Numpy array
    return next(augmented_images)  # Retrieve the first batch of augmented images

# Apply the selected augmentation method
augmented_train_images = augment_data(X_train, method='rotation')

# %% [markdown]
# # 4. Step 3: Build Stability Space using CNN + Pooling
# You now use the augmented data and pass it through a convolutional neural network with pooling to create the stability space before performing geometric separation.

# %%
import os

# Define file path to save the trained model
model_path = 'saved_models/cnn_model.keras'

# Define CNN model with input shape of (28, 28, 1) for grayscale images
def build_cnn_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  # Adjusted input shape
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')  # 10 classes for MNIST
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Check if model already exists, load it if found, otherwise train a new model
if os.path.exists(model_path):
    print("Loading pre-trained model...")
    cnn_model = tf.keras.models.load_model(model_path)
else:
    print("Training new model...")
    cnn_model = build_cnn_model()
    
    # Train the CNN model
    cnn_model.fit(augmented_train_images, y_train, epochs=10, validation_data=(X_val, y_val))
    
    # Save the trained model
    os.makedirs(os.path.dirname(model_path), exist_ok=True)  # Create directory if not exists
    cnn_model.save(model_path)
    print(f"Model saved at {model_path}")

# Use the trained model to predict probabilities on validation and test data
features_val = cnn_model.predict(X_val)
features_test = cnn_model.predict(X_test)
# Out:
# Loading pre-trained model...
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %% [markdown]
# # 5. Step 4: Apply Geometric Calibration
# Once you have the features, pass them through your GeometricCalibrator to compute the stability space and perform uncertainty calibration.

# %%
import bisect
import concurrent
from itertools import repeat
# import scann
# from annoy import AnnoyIndex
# import nmslib
# import hnswlib
import torch
import numpy as np
from sklearn.decomposition import PCA
import tensorflow as tf
from math import sqrt

import faiss
import numpy as np
from scipy.optimize import optimize, minimize
import h5py
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet, Lasso, LinearRegression
from sklearn.neighbors import NearestNeighbors
from scipy.optimize import curve_fit
from sklearn.isotonic import IsotonicRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import json
import scipy.stats
from tqdm import tqdm
import torchvision.transforms as transforms
import shutil
import time
import logging
from utils.logging_config import setup_logging
# geometric_calibrators.py
import numpy as np
import logging
from sklearn.isotonic import IsotonicRegression
from tqdm import tqdm

from calibrators.base_calibrator import BaseCalibrator
from utils.utils import StabilitySpace, Compression, calc_balanced_acc
from utils.logging_config import setup_logging
from sklearn.metrics import balanced_accuracy_score

# %%
def calc_balanced_acc(stability, y_true, y_pred, round_digits=2, num_classes=2):
    '''
    Returns the dicts of description of stability/separation (balanced accuracy, #num of True samples, #num of samples)

    Parameters:
        stability (list of floats or ndarray): Stability list of calculations
        y_true (list): Actual class labels
        y_pred (list): Predicted class labels
        round_digits (int): Number of decimal places to round the stability values to bin them
        num_classes (int): Number of unique classes in the dataset

    Returns:
        s_bal_acc (dict): {key = normalized unique stability, value = balanced accuracy for that stability}
        s_true (dict): {key = normalized unique stability, value = amount of True samples per this stability for each class}
        s_all (dict): {key = normalized unique stability, value = amount of instances exist for that stability for each class}
    '''
    logger.info("Starting the calculation of balanced accuracy.")
    # Round the stability values to the desired precision to create bins
    rounded_stability = np.round(stability, decimals=round_digits)

    # Get unique stability values and their frequencies
    stab_values, _ = np.unique(rounded_stability, return_counts=True)
    logger.info(f"Unique rounded stability values: {stab_values}")

    # Create dictionaries to count True positives and total samples per class for each stability value
    s_true = {stab: np.zeros(num_classes) for stab in stab_values}  # True positives per class
    s_all = {stab: np.zeros(num_classes) for stab in stab_values}  # Total samples per class

    # Count true positives and total samples
    for stab, true, pred in zip(rounded_stability, y_true, y_pred):
        class_index = int(true)  # Assuming y_true contains class labels from 0 to num_classes-1
        s_all[stab][class_index] += 1
        if true == pred:
            s_true[stab][class_index] += 1

    logger.info("Completed counting true positives and total samples for each stability value.")

    # Calculate balanced accuracy for each stability
    s_bal_acc = {}
    i = 0
    for stab in stab_values:
        if np.sum(s_all[stab]) == 0:  # Avoid division by zero
            s_bal_acc[stab] = 0
        else:
            # Balanced accuracy: average of recall for each class
            class_recalls = [s_true[stab][i] / s_all[stab][i] if s_all[stab][i] != 0 else 0 for i in range(num_classes)]
            s_bal_acc[stab] = np.mean(class_recalls)
        if i % 350 == 0:
            logger.info(f"Stability {stab}: Balanced Accuracy = {s_bal_acc[stab]}")
        i += 1

    return s_bal_acc, s_true, s_all

# %%
class StabilitySpace:
    """
    Class to compute stability and geometric values for the input X using various similarity search libraries.
    """

    def __init__(self, X_train, y_train, compression=None, library='faiss', metric='l2', num_labels=None):
        """
        Initialize the stability space by compressing the input data (optional) and setting up nearest neighbor models.
        """
        self.logger = logging.getLogger(self.__class__.__name__)
        self.logger.info(f"Initializing StabilitySpace with {library} library and {metric} metric.")

        self.metric = metric
        self.library = library
        self.num_labels = num_labels or len(set(y_train))
        self.compression = compression

        if self.compression:
            X_train, y_train = self.compression(X_train, y_train)

        self.X_train = X_train
        self.y_train = y_train

        self.logger.info(f"StabilitySpace initialized with {X_train.shape[0]} samples and {self.num_labels} classes.")

        # Initialize nearest neighbor indices for each class
        self.same_nbrs = {}
        self.other_nbrs = {}
        self._build_neighbors_indices()
        # Initialize the stability_calculators dictionary
        self.stability_calculators = {
            'faiss': self._stability_faiss_knn,
            'knn': self._stability_faiss_knn,  # Reuse the same function for KNN
            # Other libraries like 'annoy', 'nmslib', etc. can be added here if needed
        }        

    def _build_neighbors_indices(self):
        """
        Build nearest-neighbor indices for same and other classes.
        """
        self.logger.info("Starting to build nearest-neighbor indices for each class.")
    
        # Reshape X_train if it's multi-dimensional (for example, if it's an image dataset)
        if len(self.X_train.shape) > 2:
            self.logger.debug("Reshaping X_train for FAISS/KNN compatibility.")
            self.X_train = self.X_train.reshape(self.X_train.shape[0], -1).astype('float32')
    
        dim = self.X_train.shape[1]  # Now dim should be the number of features per sample
        self.logger.info(f"Number of features per sample: {dim}")
    
        # Build separate FAISS indices for same and other-class samples
        for label in range(self.num_labels):
            self.logger.info(f"Processing label {label}/{self.num_labels - 1}.")
    
            # Get indices of samples with the same and different labels
            idx_same = np.where(self.y_train == label)[0]
            idx_other = np.where(self.y_train != label)[0]
    
            if self.library == 'faiss':
                self.logger.info(f"Using FAISS for label {label}.")
    
                # Build FAISS index for same-class data
                try:
                    self.same_nbrs[label] = faiss.IndexFlatL2(dim)
                    self.same_nbrs[label].add(self.X_train[idx_same].astype('float32'))
                    self.logger.info(f"FAISS index for same-class built successfully for label {label}.")
                except Exception as e:
                    self.logger.error(f"Error building FAISS index for same-class for label {label}: {e}")
    
                # Build FAISS index for other-class data
                try:
                    self.other_nbrs[label] = faiss.IndexFlatL2(dim)
                    self.other_nbrs[label].add(self.X_train[idx_other].astype('float32'))
                    self.logger.info(f"FAISS index for other-class built successfully for label {label}.")
                except Exception as e:
                    self.logger.error(f"Error building FAISS index for other-class for label {label}: {e}")
    
    def _stability_faiss_knn(self, trainX, testX, train_y, test_y_pred, num_labels, metric='l2'):
        """
        Calculates the stability of the test set using FAISS or KNN (depending on the prebuilt indices).
        """
        logger.info(f"Starting stability calculation using {self.library} with metric: {metric}.")
        predicted_labels = np.argmax(test_y_pred, axis=1)
        stability = np.zeros(len(testX))

        for i in tqdm(range(testX.shape[0]), desc="Calculating Stability", unit="sample"):
            x = testX[i].reshape(1, -1)  # Flatten the test instance
            pred_label = int(predicted_labels[i])

            if self.library == 'faiss':
                _, dist_same = self.same_nbrs[pred_label].search(x, 1)  # Nearest in same class
                _, dist_other = self.other_nbrs[pred_label].search(x, 1)  # Nearest in other classes

            stability[i] = (dist_other[0][0] - dist_same[0][0]) / 2

        logger.info("Completed stability calculation.")
        return stability

    def calc_stab(self, X_test, y_test_pred):
        """
        Calculate stability for the test set.
        """
        if self.compression:
            X_test, _ = self.compression(X_test, None, train=False)

        self.logger.info(f"Calculating stability using {self.library} with metric {self.metric}.")
        stability_calculator = self.stability_calculators.get(self.library)

        if stability_calculator is not None:
            return stability_calculator(self.X_train, X_test, self.y_train, y_test_pred, self.num_labels, metric=self.metric)
        else:
            self.logger.error(f"Unsupported library: {self.library}")
            raise ValueError(f"Unsupported library: {self.library}")
            
    def calc_balanced_accuracy(self, stability, y_true, y_pred):
        """
        Calculate balanced accuracy for each unique stability value in classification using sklearn.
        """
        unique_stabilities = np.unique(stability)
        balanced_accuracies = {}

        for stab in unique_stabilities:
            # Mask for current stability value
            mask = stability == stab
            if np.any(mask):
                # Calculate balanced accuracy for the current stability subset
                balanced_accuracies[stab] = balanced_accuracy_score(y_true[mask], y_pred[mask])

        return balanced_accuracies
        
    def calculate_stability_and_accuracy(self, X_test, y_test_true, y_test_pred):
        """
        A method to calculate both stability and balanced accuracy for the given test dataset.
        """
        stability = self.calc_stab(X_test, y_test_pred)
        balanced_accuracy = self.calc_balanced_accuracy(stability, y_test_true, y_test_pred)

        return stability, balanced_accuracy

# %%
setup_logging()
logger = logging.getLogger(__name__)


class GeometricCalibrator(BaseCalibrator):
    """
    Class serving as a wrapper for the geometric calibration method (stability/separation).
    """

    def __init__(self, model, X_train, y_train, fitting_func=None, compression_mode=None, compression_param=None,
                 metric='l2', stability_space=None, library='faiss'):
        """
        Initializes the GeometricCalibrator with a model, stability space, and calibration function.

        Args:
            model: The model to be calibrated (with `predict` and `predict_proba` methods).
            X_train: Training data (flattened images).
            y_train: Training labels.
            fitting_func: Custom fitting function (default: IsotonicRegression).
            compression_mode: Compression mode for data.
            compression_param: Parameter controlling the compression level.
            metric: Distance metric for stability/separation calculations.
            stability_space: Optional custom StabilitySpace instance. If not provided, one is initialized automatically.
            library: The library used for stability calculation (default is 'faiss').
        """
        super().__init__()
        self.model = model
        self.popt = None
        self._fitted = False

        # Determine the number of classes (unique labels in y_train)
        self.num_labels = len(np.unique(y_train))  # Fix: Initialize num_labels based on the training labels

        # Default to IsotonicRegression if no custom fitting function is provided
        self.fitting_func = fitting_func if fitting_func else IsotonicRegression(out_of_bounds="clip")

        # Use provided stability space or create a new one with the default settings
        if stability_space:
            self.stab_space = stability_space  # User provided custom StabilitySpace
            logger.info(f"{self.__class__.__name__}: Using custom StabilitySpace provided by user.")
        else:
            # Automatically initialize StabilitySpace with defaults if not provided
            self.stab_space = StabilitySpace(X_train, y_train,
                                             compression=Compression(compression_mode, compression_param),
                                             library=library, metric=metric)
            logger.info(f"{self.__class__.__name__}: Initialized StabilitySpace with default settings"
                        f" (library: {library}, metric: {metric}).")

        logger.info(f"Initialized {self.__class__.__name__} with model {self.model.__class__.__name__}"
                    f" and fitting function {self.fitting_func.__class__.__name__}.")

    def fit(self, X_val, y_val):
        """
        Fits the calibrator with the validation data using rounded stability and balanced accuracy.
    
        Args:
            X_val: Validation data (flattened images).
            y_val: Validation labels.
        """
        logger.info(f"{self.__class__.__name__}: Fitting with validation data using balanced accuracy and rounded stability.")
    
        try:
            # Step 1: Predict on validation data
            y_pred_val = self.model.predict(X_val)
            y_pred_classes = np.argmax(y_pred_val, axis=1)  # Convert predictions to class labels
    
            # Step 2: Compute stability values based on predictions
            stability_val = self.stab_space.calc_stab(X_val, y_pred_val)
            logger.info(f"Stability values (first 200): {stability_val[:200]}")  # Log a sample of the stability values
    
            # Step 3: Round the stability values for binning
            round_digits = 5  # Precision for rounding stability values
            rounded_stability = np.round(stability_val, decimals=round_digits)
            unique_stabilities = np.unique(rounded_stability)
    
            # Step 4: Calculate accuracy for each unique stability value
            stability_accuracy = {}
            i = 0
            for stab in unique_stabilities:
                indices = np.where(rounded_stability == stab)[0]  # Get indices of points with this stability
                y_true_stab = y_val[indices]  # Get true labels for these points
                y_pred_stab = y_pred_classes[indices]  # Get predicted labels for these points
    
                # Calculate balanced accuracy for this stability value
                if len(np.unique(y_true_stab)) > 1:  # Ensure we have more than one class
                    acc = balanced_accuracy_score(y_true_stab, y_pred_stab)
                else:
                    acc = np.mean(y_true_stab == y_pred_stab)  # Use normal accuracy for single-class stability
    
                stability_accuracy[stab] = acc
                if i % 350 == 0:
                    logger.info(f"Stability {stab}: Accuracy = {acc}")
                i += 1
    
            # Step 5: Prepare calibration data: (rounded_stability, accuracy) pairs
            calibration_data = [(stab, stability_accuracy[stab]) for stab in stability_accuracy]
    
            # Step 6: Fit the provided fitting function (e.g., IsotonicRegression) on the calibration data
            stability_vals, accuracies = zip(*calibration_data)
            self.popt = self.fitting_func.fit(np.array(stability_vals).reshape(-1, 1), np.array(accuracies))
    
            self._fitted = True
            logger.info(f"{self.__class__.__name__}: Successfully fitted using stability-accuracy pairs and {self.fitting_func.__class__.__name__}.")
    
        except Exception as e:
            logger.error(f"{self.__class__.__name__}: Failed to fit with error: {e}")
            raise
            
    def calibrate(self, X_test):
        """
        Calibrates the test data based on the fitted model.
    
        Args:
            X_test: Test data (flattened images).
    
        Returns:
            np.ndarray: Calibrated probability matrix for each image and class.
        """
        if not self._fitted:
            raise ValueError("You must fit the calibrator before using it.")
    
        logger.info(f"{self.__class__.__name__}: Calibrating test data.")
    
        try:
            # Predict on the test data using the trained model (get predicted probabilities for all classes)
            y_test_pred = self.model.predict(X_test)
            y_test_labels = np.argmax(y_test_pred, axis=1)  # Get predicted class labels from probabilities
    
            # Initialize progress bar using tqdm
            num_samples = X_test.shape[0]
            num_classes = y_test_pred.shape[1]
            calibrated_probs = np.zeros((num_samples, num_classes))  # Initialize a matrix to store calibrated probabilities
    
            logger.info(f"Starting calibration for {num_samples} samples and {num_classes} classes.")
    
            # Compute stability for the predicted probabilities
            stability_test = self.stab_space.calc_stab(X_test, y_test_pred)
            logger.info(f"Stability values during calibration (first 10): {stability_test[:10]}")  # Add logging
    
            # Apply the fitted calibration function to the stability values
            calibrated_values = self.popt.predict(stability_test.reshape(-1, 1))
            logger.info(f"Calibrated values (first 10): {calibrated_values[:10]}")  # Add logging
    
            # Distribute the calibrated values across the predicted class
            for i in range(X_test.shape[0]):
                # Assign the calibrated probability to the predicted class label
                calibrated_probs[i, y_test_labels[i]] = calibrated_values[i]
                
                # Distribute remaining probability equally across other classes
                remaining_prob = (1 - calibrated_values[i]) / (self.num_labels - 1)
                for j in range(self.num_labels):
                    if j != y_test_labels[i]:
                        calibrated_probs[i, j] = remaining_prob
    
            # Ensure probabilities are in [0, 1] and sum to 1
            calibrated_probs = np.clip(calibrated_probs, 0, 1)
            calibrated_probs = calibrated_probs / calibrated_probs.sum(axis=1, keepdims=True)
    
            logger.info(f"{self.__class__.__name__}: Calibration successful.")
    
            return calibrated_probs
    
        except Exception as e:
            logger.error(f"{self.__class__.__name__}: Calibration failed with error: {e}")
            raise

# %%
# Initialize Geometric Calibrator with FAISS
geo_calibrator_faiss = GeometricCalibrator(model=cnn_model, X_train=augmented_train_images, y_train=y_train, library='faiss')

# Fit the calibrator using FAISS on the validation data
geo_calibrator_faiss.fit(X_val, y_val)

# # Initialize Geometric Calibrator with KNN
# geo_calibrator_knn = GeometricCalibrator(model=cnn_model, X_train=augmented_train_images, y_train=y_train, library='knn')

# # Fit the calibrator using KNN on the validation data
# geo_calibrator_knn.fit(X_val, y_val)

print("Both FAISS and KNN calibrators have been initialized and fitted.")
# Out:
# 2024-09-24 14:06:35,729 - INFO - Initialized GeometricCalibrator with n_classes=None, bins=15, temperature=1.0
# 2024-09-24 14:06:35,731 - INFO - Initializing StabilitySpace with faiss library and l2 metric.
# 2024-09-24 14:06:35,738 - INFO - StabilitySpace initialized with 42000 samples and 10 classes.
# 2024-09-24 14:06:35,739 - INFO - Starting to build nearest-neighbor indices for each class.
# Running without compression, the shape of X needs to be square
# 2024-09-24 14:06:39,493 - INFO - Number of features per sample: 784
# 2024-09-24 14:06:39,494 - INFO - Processing label 0/9.
# 2024-09-24 14:06:39,495 - INFO - Using FAISS for label 0.
# 2024-09-24 14:06:41,007 - INFO - FAISS index for same-class built successfully for label 0.
# 2024-09-24 14:07:12,609 - INFO - FAISS index for other-class built successfully for label 0.
# 2024-09-24 14:07:12,610 - INFO - Processing label 1/9.
# 2024-09-24 14:07:12,612 - INFO - Using FAISS for label 1.
# 2024-09-24 14:07:12,638 - INFO - FAISS index for same-class built successfully for label 1.
# 2024-09-24 14:07:20,467 - INFO - FAISS index for other-class built successfully for label 1.
# 2024-09-24 14:07:20,468 - INFO - Processing label 2/9.
# 2024-09-24 14:07:20,469 - INFO - Using FAISS for label 2.
# 2024-09-24 14:07:20,489 - INFO - FAISS index for same-class built successfully for label 2.
# 2024-09-24 14:07:20,809 - INFO - FAISS index for other-class built successfully for label 2.
# 2024-09-24 14:07:20,810 - INFO - Processing label 3/9.
# 2024-09-24 14:07:20,811 - INFO - Using FAISS for label 3.
# 2024-09-24 14:07:20,833 - INFO - FAISS index for same-class built successfully for label 3.
# 2024-09-24 14:07:21,159 - INFO - FAISS index for other-class built successfully for label 3.
# 2024-09-24 14:07:21,160 - INFO - Processing label 4/9.
# 2024-09-24 14:07:21,161 - INFO - Using FAISS for label 4.
# 2024-09-24 14:07:21,187 - INFO - FAISS index for same-class built successfully for label 4.
# 2024-09-24 14:07:21,515 - INFO - FAISS index for other-class built successfully for label 4.
# 2024-09-24 14:07:21,516 - INFO - Processing label 5/9.
# 2024-09-24 14:07:21,517 - INFO - Using FAISS for label 5.
# 2024-09-24 14:07:21,540 - INFO - FAISS index for same-class built successfully for label 5.
# 2024-09-24 14:07:21,869 - INFO - FAISS index for other-class built successfully for label 5.
# 2024-09-24 14:07:21,870 - INFO - Processing label 6/9.
# 2024-09-24 14:07:21,872 - INFO - Using FAISS for label 6.
# 2024-09-24 14:07:21,897 - INFO - FAISS index for same-class built successfully for label 6.
# 2024-09-24 14:07:22,226 - INFO - FAISS index for other-class built successfully for label 6.
# 2024-09-24 14:07:22,227 - INFO - Processing label 7/9.
# 2024-09-24 14:07:22,228 - INFO - Using FAISS for label 7.
# 2024-09-24 14:07:22,255 - INFO - FAISS index for same-class built successfully for label 7.
# 2024-09-24 14:07:22,582 - INFO - FAISS index for other-class built successfully for label 7.
# 2024-09-24 14:07:22,583 - INFO - Processing label 8/9.
# 2024-09-24 14:07:22,585 - INFO - Using FAISS for label 8.
# 2024-09-24 14:07:22,608 - INFO - FAISS index for same-class built successfully for label 8.
# 2024-09-24 14:07:22,935 - INFO - FAISS index for other-class built successfully for label 8.
# 2024-09-24 14:07:22,936 - INFO - Processing label 9/9.
# 2024-09-24 14:07:22,937 - INFO - Using FAISS for label 9.
# 2024-09-24 14:07:22,963 - INFO - FAISS index for same-class built successfully for label 9.
# 2024-09-24 14:07:23,293 - INFO - FAISS index for other-class built successfully for label 9.
# 2024-09-24 14:07:23,294 - INFO - GeometricCalibrator: Initialized StabilitySpace with default settings (library: faiss, metric: l2).
# 2024-09-24 14:07:23,294 - INFO - Initialized GeometricCalibrator with model Sequential and fitting function IsotonicRegression.
# 2024-09-24 14:07:23,295 - INFO - GeometricCalibrator: Fitting with validation data using balanced accuracy and rounded stability.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# 2024-09-24 14:07:26,552 - INFO - Calculating stability using faiss with metric l2.
# 2024-09-24 14:07:26,553 - INFO - Starting stability calculation using faiss with metric: l2.
# Running without compression, the shape of X needs to be square
# Calculating Stability: 100%|██████████| 14000/14000 [04:00<00:00, 58.11sample/s]
# 2024-09-24 14:11:27,484 - INFO - Completed stability calculation.
# 2024-09-24 14:11:27,487 - INFO - Stability values (first 200): [10323.  10775.5  6828.  11233.   5364.5 15242.5  9082.   3573.5  4628.
#   4009.   8945.  16456.5 17064.  14602.5 10527.   -315.5  9867.   8717.
#   3271.5 17258.5  8129.5   452.  16059.   5790.5 13773.   7730.5  4651.
#  13388.  18062.5  1359.5 16414.   9206.   9134.5  5459.   -361.5  2337.
#   8511.  14318.   7120.5  4837.5   474.  10053.   2009.   1643.5 17095.5
#   1501.  10611.  17493.    -89.  15377.5 13833.5   476.5 16573.5  7034.5
#   6665.5 15093.   9847.  15710.5  5595.  10347.  14083.  16095.5 14662.5
#  17695.5 18497.  16576.5  5516.5 10561.  15031.  17525.5  5984.5  4590.
#   -624.  12844.   3362.5  8933.   4318.   6106.5 16106.   7887.   8475.
#   6920.   8496.5  3307.5  9301.  14182.5  -193.5  -352.5  8466.5  -214.
#    283.5 16627.5  1765.  17464.  -1301.  12370.5  4872.5 14524.5 11575.5
#   7207.   7122.5  7524.5    81.   5382.   2570.    -54.5 10173.5 17258.5
#   8760.   5161.5   974.  14676.5  3155.5  9804.   8237.5  5914.  14370.5
#   8482.5 10513.5  7878.5 12319.5  8181.5  4896.  14291.5  2905.5  5785.
#  13291.5  5250.5  -597.   5926.5 13333.   1101.  11920.   5555.  15558.5
#  13678.5  8276.5 11655.   5551.   3274.5  4899.   3854.5 16951.   9199.
#  14948.5 12481.5 16685.5  9305.   4016.5  8086.5 14435.  10537.5  8228.5
#  15007.   4756.   7451.  12193.   7598.   8011.    221.5 15692.5 12426.
#   1216.5  2621.5  7650.   1568.  18367.5 13096.  17393.  17280.5  4280.
#  15127.   7954.5  3200.  14289.  12793.5  2190.   1032.5 10801.5  1282.
#  15255.    319.  16206.   7430.  10887.5 15707.5 11842.  11167.5  4853.
#   2042.  16585.  15122.5  1503.   7027.5  8675.5  4652.  11909.5  2153.5
#  14217.5 12950.5]
# 2024-09-24 14:11:27,490 - INFO - Stability -2118.0: Accuracy = 1.0
# 2024-09-24 14:11:27,491 - INFO - Stability -2039.0: Accuracy = 1.0
# 2024-09-24 14:11:27,491 - INFO - Stability -2037.5: Accuracy = 1.0
# 2024-09-24 14:11:27,492 - INFO - Stability -2014.5: Accuracy = 1.0
# 2024-09-24 14:11:27,493 - INFO - Stability -2011.5: Accuracy = 0.0
# 2024-09-24 14:11:27,494 - INFO - Stability -2006.5: Accuracy = 1.0
# 2024-09-24 14:11:27,495 - INFO - Stability -1987.0: Accuracy = 1.0
# 2024-09-24 14:11:27,497 - INFO - Stability -1978.5: Accuracy = 1.0
# 2024-09-24 14:11:27,498 - INFO - Stability -1975.5: Accuracy = 1.0
# 2024-09-24 14:11:27,499 - INFO - Stability -1974.5: Accuracy = 1.0
# 2024-09-24 14:11:27,500 - INFO - Stability -1963.0: Accuracy = 1.0
# 2024-09-24 14:11:27,501 - INFO - Stability -1945.0: Accuracy = 1.0
# 2024-09-24 14:11:27,502 - INFO - Stability -1934.5: Accuracy = 1.0
# 2024-09-24 14:11:27,503 - INFO - Stability -1896.0: Accuracy = 1.0
# 2024-09-24 14:11:27,504 - INFO - Stability -1884.5: Accuracy = 1.0
# 2024-09-24 14:11:27,504 - INFO - Stability -1876.5: Accuracy = 1.0
# 2024-09-24 14:11:27,506 - INFO - Stability -1870.0: Accuracy = 1.0
# 2024-09-24 14:11:27,507 - INFO - Stability -1813.5: Accuracy = 1.0
# 2024-09-24 14:11:27,507 - INFO - Stability -1805.5: Accuracy = 1.0
# 2024-09-24 14:11:27,508 - INFO - Stability -1800.0: Accuracy = 1.0
# 2024-09-24 14:11:27,509 - INFO - Stability -1785.0: Accuracy = 1.0
# 2024-09-24 14:11:27,509 - INFO - Stability -1774.0: Accuracy = 1.0
# 2024-09-24 14:11:27,510 - INFO - Stability -1763.0: Accuracy = 1.0
# 2024-09-24 14:11:27,512 - INFO - Stability -1758.0: Accuracy = 0.0
# 2024-09-24 14:11:27,512 - INFO - Stability -1752.5: Accuracy = 1.0
# 2024-09-24 14:11:27,514 - INFO - Stability -1748.0: Accuracy = 1.0
# 2024-09-24 14:11:27,515 - INFO - Stability -1741.5: Accuracy = 1.0
# 2024-09-24 14:11:27,516 - INFO - Stability -1729.0: Accuracy = 1.0
# 2024-09-24 14:11:27,517 - INFO - Stability -1724.5: Accuracy = 0.0
# 2024-09-24 14:11:27,518 - INFO - Stability -1713.5: Accuracy = 1.0
# 2024-09-24 14:11:27,519 - INFO - Stability -1709.5: Accuracy = 0.0
# 2024-09-24 14:11:27,520 - INFO - Stability -1633.5: Accuracy = 1.0
# 2024-09-24 14:11:27,521 - INFO - Stability -1632.5: Accuracy = 1.0
# 2024-09-24 14:11:27,522 - INFO - Stability -1626.5: Accuracy = 1.0
# 2024-09-24 14:11:27,523 - INFO - Stability -1616.0: Accuracy = 1.0
# 2024-09-24 14:11:27,524 - INFO - Stability -1595.0: Accuracy = 1.0
# 2024-09-24 14:11:27,525 - INFO - Stability -1594.0: Accuracy = 1.0
# 2024-09-24 14:11:27,526 - INFO - Stability -1593.0: Accuracy = 1.0
# 2024-09-24 14:11:27,527 - INFO - Stability -1590.5: Accuracy = 1.0
# 2024-09-24 14:11:27,528 - INFO - Stability -1582.0: Accuracy = 1.0
# 2024-09-24 14:11:27,529 - INFO - Stability -1581.0: Accuracy = 0.0
# 2024-09-24 14:11:27,530 - INFO - Stability -1577.5: Accuracy = 1.0
# 2024-09-24 14:11:27,531 - INFO - Stability -1569.5: Accuracy = 1.0
# 2024-09-24 14:11:27,532 - INFO - Stability -1569.0: Accuracy = 1.0
# 2024-09-24 14:11:27,533 - INFO - Stability -1563.5: Accuracy = 1.0
# 2024-09-24 14:11:27,534 - INFO - Stability -1558.5: Accuracy = 1.0
# 2024-09-24 14:11:27,535 - INFO - Stability -1556.0: Accuracy = 1.0
# 2024-09-24 14:11:27,536 - INFO - Stability -1554.0: Accuracy = 1.0
# 2024-09-24 14:11:27,537 - INFO - Stability -1528.5: Accuracy = 0.0
# 2024-09-24 14:11:27,538 - INFO - Stability -1524.0: Accuracy = 1.0
# 2024-09-24 14:11:27,539 - INFO - Stability -1520.5: Accuracy = 1.0
# 2024-09-24 14:11:27,540 - INFO - Stability -1516.5: Accuracy = 1.0
# 2024-09-24 14:11:27,540 - INFO - Stability -1510.5: Accuracy = 1.0
# 2024-09-24 14:11:27,541 - INFO - Stability -1510.0: Accuracy = 1.0
# 2024-09-24 14:11:27,542 - INFO - Stability -1508.5: Accuracy = 1.0
# 2024-09-24 14:11:27,544 - INFO - Stability -1500.0: Accuracy = 0.0
# 2024-09-24 14:11:27,545 - INFO - Stability -1498.0: Accuracy = 1.0
# 2024-09-24 14:11:27,546 - INFO - Stability -1493.0: Accuracy = 1.0
# 2024-09-24 14:11:27,547 - INFO - Stability -1490.0: Accuracy = 1.0
# 2024-09-24 14:11:27,548 - INFO - Stability -1489.5: Accuracy = 1.0
# 2024-09-24 14:11:27,549 - INFO - Stability -1489.0: Accuracy = 1.0
# 2024-09-24 14:11:27,550 - INFO - Stability -1486.0: Accuracy = 1.0
# 2024-09-24 14:11:27,551 - INFO - Stability -1482.0: Accuracy = 1.0
# 2024-09-24 14:11:27,552 - INFO - Stability -1467.5: Accuracy = 1.0
# 2024-09-24 14:11:27,553 - INFO - Stability -1461.0: Accuracy = 1.0
# 2024-09-24 14:11:27,554 - INFO - Stability -1450.5: Accuracy = 1.0
# 2024-09-24 14:11:27,555 - INFO - Stability -1449.5: Accuracy = 1.0
# 2024-09-24 14:11:27,556 - INFO - Stability -1448.5: Accuracy = 1.0
# 2024-09-24 14:11:27,557 - INFO - Stability -1439.5: Accuracy = 0.0
# 2024-09-24 14:11:27,558 - INFO - Stability -1436.5: Accuracy = 1.0
# 2024-09-24 14:11:27,559 - INFO - Stability -1435.5: Accuracy = 1.0
# 2024-09-24 14:11:27,560 - INFO - Stability -1423.5: Accuracy = 1.0
# 2024-09-24 14:11:27,561 - INFO - Stability -1422.5: Accuracy = 1.0
# 2024-09-24 14:11:27,562 - INFO - Stability -1413.5: Accuracy = 1.0
# 2024-09-24 14:11:27,563 - INFO - Stability -1412.5: Accuracy = 1.0
# 2024-09-24 14:11:27,563 - INFO - Stability -1410.0: Accuracy = 1.0
# 2024-09-24 14:11:27,565 - INFO - Stability -1408.0: Accuracy = 1.0
# 2024-09-24 14:11:27,566 - INFO - Stability -1405.5: Accuracy = 1.0
# 2024-09-24 14:11:27,567 - INFO - Stability -1398.5: Accuracy = 1.0
# 2024-09-24 14:11:27,645 - INFO - Stability -1396.5: Accuracy = 1.0
# 2024-09-24 14:11:27,646 - INFO - Stability -1390.5: Accuracy = 1.0
# 2024-09-24 14:11:27,647 - INFO - Stability -1388.0: Accuracy = 1.0
# 2024-09-24 14:11:27,648 - INFO - Stability -1372.5: Accuracy = 1.0
# 2024-09-24 14:11:27,649 - INFO - Stability -1371.5: Accuracy = 0.0
# 2024-09-24 14:11:27,650 - INFO - Stability -1370.0: Accuracy = 1.0
# 2024-09-24 14:11:27,651 - INFO - Stability -1366.0: Accuracy = 1.0
# 2024-09-24 14:11:27,652 - INFO - Stability -1364.5: Accuracy = 1.0
# 2024-09-24 14:11:27,652 - INFO - Stability -1361.5: Accuracy = 1.0
# 2024-09-24 14:11:27,653 - INFO - Stability -1357.5: Accuracy = 1.0
# 2024-09-24 14:11:27,654 - INFO - Stability -1354.0: Accuracy = 1.0
# 2024-09-24 14:11:27,655 - INFO - Stability -1352.0: Accuracy = 1.0
# 2024-09-24 14:11:27,656 - INFO - Stability -1349.0: Accuracy = 1.0
# 2024-09-24 14:11:27,657 - INFO - Stability -1345.5: Accuracy = 1.0
# 2024-09-24 14:11:27,658 - INFO - Stability -1344.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:27,696 - INFO - Stability -1342.0: Accuracy = 0.5
# 2024-09-24 14:11:27,697 - INFO - Stability -1340.5: Accuracy = 1.0
# 2024-09-24 14:11:27,698 - INFO - Stability -1339.0: Accuracy = 1.0
# 2024-09-24 14:11:27,699 - INFO - Stability -1328.5: Accuracy = 1.0
# 2024-09-24 14:11:27,700 - INFO - Stability -1311.5: Accuracy = 1.0
# 2024-09-24 14:11:27,701 - INFO - Stability -1307.0: Accuracy = 1.0
# 2024-09-24 14:11:27,701 - INFO - Stability -1306.5: Accuracy = 1.0
# 2024-09-24 14:11:27,703 - INFO - Stability -1301.0: Accuracy = 1.0
# 2024-09-24 14:11:27,704 - INFO - Stability -1294.0: Accuracy = 1.0
# 2024-09-24 14:11:27,705 - INFO - Stability -1286.0: Accuracy = 1.0
# 2024-09-24 14:11:27,706 - INFO - Stability -1284.0: Accuracy = 1.0
# 2024-09-24 14:11:27,707 - INFO - Stability -1278.0: Accuracy = 1.0
# 2024-09-24 14:11:27,708 - INFO - Stability -1277.0: Accuracy = 1.0
# 2024-09-24 14:11:27,709 - INFO - Stability -1265.0: Accuracy = 1.0
# 2024-09-24 14:11:27,710 - INFO - Stability -1260.0: Accuracy = 1.0
# 2024-09-24 14:11:27,711 - INFO - Stability -1254.5: Accuracy = 0.0
# 2024-09-24 14:11:27,713 - INFO - Stability -1253.0: Accuracy = 1.0
# 2024-09-24 14:11:27,713 - INFO - Stability -1250.5: Accuracy = 1.0
# 2024-09-24 14:11:27,714 - INFO - Stability -1237.0: Accuracy = 1.0
# 2024-09-24 14:11:27,715 - INFO - Stability -1236.5: Accuracy = 1.0
# 2024-09-24 14:11:27,716 - INFO - Stability -1235.5: Accuracy = 0.0
# 2024-09-24 14:11:27,716 - INFO - Stability -1233.0: Accuracy = 1.0
# 2024-09-24 14:11:27,717 - INFO - Stability -1226.0: Accuracy = 1.0
# 2024-09-24 14:11:27,718 - INFO - Stability -1215.0: Accuracy = 1.0
# 2024-09-24 14:11:27,721 - INFO - Stability -1204.0: Accuracy = 1.0
# 2024-09-24 14:11:27,722 - INFO - Stability -1201.5: Accuracy = 1.0
# 2024-09-24 14:11:27,723 - INFO - Stability -1190.5: Accuracy = 0.0
# 2024-09-24 14:11:27,724 - INFO - Stability -1188.5: Accuracy = 1.0
# 2024-09-24 14:11:27,725 - INFO - Stability -1186.0: Accuracy = 1.0
# 2024-09-24 14:11:27,726 - INFO - Stability -1178.0: Accuracy = 1.0
# 2024-09-24 14:11:27,727 - INFO - Stability -1177.0: Accuracy = 1.0
# 2024-09-24 14:11:27,728 - INFO - Stability -1176.5: Accuracy = 1.0
# 2024-09-24 14:11:27,729 - INFO - Stability -1175.5: Accuracy = 1.0
# 2024-09-24 14:11:27,730 - INFO - Stability -1175.0: Accuracy = 1.0
# 2024-09-24 14:11:27,731 - INFO - Stability -1172.5: Accuracy = 1.0
# 2024-09-24 14:11:27,732 - INFO - Stability -1170.5: Accuracy = 1.0
# 2024-09-24 14:11:27,733 - INFO - Stability -1168.0: Accuracy = 1.0
# 2024-09-24 14:11:27,734 - INFO - Stability -1162.0: Accuracy = 1.0
# 2024-09-24 14:11:27,735 - INFO - Stability -1157.5: Accuracy = 1.0
# 2024-09-24 14:11:27,736 - INFO - Stability -1156.0: Accuracy = 1.0
# 2024-09-24 14:11:27,737 - INFO - Stability -1152.5: Accuracy = 0.0
# 2024-09-24 14:11:27,738 - INFO - Stability -1149.0: Accuracy = 1.0
# 2024-09-24 14:11:27,739 - INFO - Stability -1138.5: Accuracy = 0.0
# 2024-09-24 14:11:27,740 - INFO - Stability -1135.5: Accuracy = 1.0
# 2024-09-24 14:11:27,741 - INFO - Stability -1126.5: Accuracy = 1.0
# 2024-09-24 14:11:27,742 - INFO - Stability -1123.0: Accuracy = 1.0
# 2024-09-24 14:11:27,742 - INFO - Stability -1118.0: Accuracy = 1.0
# 2024-09-24 14:11:27,743 - INFO - Stability -1110.5: Accuracy = 1.0
# 2024-09-24 14:11:27,744 - INFO - Stability -1106.5: Accuracy = 1.0
# 2024-09-24 14:11:27,744 - INFO - Stability -1103.5: Accuracy = 1.0
# 2024-09-24 14:11:27,746 - INFO - Stability -1103.0: Accuracy = 1.0
# 2024-09-24 14:11:27,747 - INFO - Stability -1094.0: Accuracy = 1.0
# 2024-09-24 14:11:27,748 - INFO - Stability -1088.5: Accuracy = 1.0
# 2024-09-24 14:11:27,749 - INFO - Stability -1083.5: Accuracy = 1.0
# 2024-09-24 14:11:27,750 - INFO - Stability -1083.0: Accuracy = 1.0
# 2024-09-24 14:11:27,751 - INFO - Stability -1079.5: Accuracy = 1.0
# 2024-09-24 14:11:27,752 - INFO - Stability -1079.0: Accuracy = 1.0
# 2024-09-24 14:11:27,752 - INFO - Stability -1076.0: Accuracy = 1.0
# 2024-09-24 14:11:27,754 - INFO - Stability -1075.5: Accuracy = 0.0
# 2024-09-24 14:11:27,754 - INFO - Stability -1070.0: Accuracy = 1.0
# 2024-09-24 14:11:27,755 - INFO - Stability -1063.0: Accuracy = 1.0
# 2024-09-24 14:11:27,756 - INFO - Stability -1050.5: Accuracy = 1.0
# 2024-09-24 14:11:27,757 - INFO - Stability -1046.5: Accuracy = 1.0
# 2024-09-24 14:11:27,758 - INFO - Stability -1039.0: Accuracy = 1.0
# 2024-09-24 14:11:27,759 - INFO - Stability -1029.5: Accuracy = 1.0
# 2024-09-24 14:11:27,760 - INFO - Stability -1028.5: Accuracy = 1.0
# 2024-09-24 14:11:27,761 - INFO - Stability -1024.0: Accuracy = 1.0
# 2024-09-24 14:11:27,761 - INFO - Stability -1016.5: Accuracy = 1.0
# 2024-09-24 14:11:27,762 - INFO - Stability -1015.5: Accuracy = 1.0
# 2024-09-24 14:11:27,765 - INFO - Stability -1011.5: Accuracy = 1.0
# 2024-09-24 14:11:27,766 - INFO - Stability -1006.0: Accuracy = 1.0
# 2024-09-24 14:11:27,766 - INFO - Stability -1001.5: Accuracy = 1.0
# 2024-09-24 14:11:27,768 - INFO - Stability -999.5: Accuracy = 1.0
# 2024-09-24 14:11:27,768 - INFO - Stability -992.5: Accuracy = 1.0
# 2024-09-24 14:11:27,769 - INFO - Stability -991.0: Accuracy = 1.0
# 2024-09-24 14:11:27,770 - INFO - Stability -989.5: Accuracy = 1.0
# 2024-09-24 14:11:27,771 - INFO - Stability -987.0: Accuracy = 1.0
# 2024-09-24 14:11:27,771 - INFO - Stability -985.5: Accuracy = 1.0
# 2024-09-24 14:11:27,772 - INFO - Stability -984.5: Accuracy = 1.0
# 2024-09-24 14:11:27,774 - INFO - Stability -983.0: Accuracy = 1.0
# 2024-09-24 14:11:27,774 - INFO - Stability -982.0: Accuracy = 1.0
# 2024-09-24 14:11:27,775 - INFO - Stability -980.0: Accuracy = 1.0
# 2024-09-24 14:11:27,776 - INFO - Stability -972.0: Accuracy = 1.0
# 2024-09-24 14:11:27,777 - INFO - Stability -967.5: Accuracy = 1.0
# 2024-09-24 14:11:27,778 - INFO - Stability -966.5: Accuracy = 1.0
# 2024-09-24 14:11:27,779 - INFO - Stability -965.0: Accuracy = 1.0
# 2024-09-24 14:11:27,780 - INFO - Stability -963.0: Accuracy = 1.0
# 2024-09-24 14:11:27,781 - INFO - Stability -961.0: Accuracy = 1.0
# 2024-09-24 14:11:27,782 - INFO - Stability -955.5: Accuracy = 1.0
# 2024-09-24 14:11:27,783 - INFO - Stability -951.0: Accuracy = 1.0
# 2024-09-24 14:11:27,784 - INFO - Stability -950.0: Accuracy = 0.0
# 2024-09-24 14:11:27,785 - INFO - Stability -948.5: Accuracy = 1.0
# 2024-09-24 14:11:27,788 - INFO - Stability -942.5: Accuracy = 1.0
# 2024-09-24 14:11:27,789 - INFO - Stability -941.5: Accuracy = 1.0
# 2024-09-24 14:11:27,790 - INFO - Stability -930.0: Accuracy = 1.0
# 2024-09-24 14:11:27,790 - INFO - Stability -929.0: Accuracy = 1.0
# 2024-09-24 14:11:27,791 - INFO - Stability -923.5: Accuracy = 1.0
# 2024-09-24 14:11:27,792 - INFO - Stability -920.5: Accuracy = 1.0
# 2024-09-24 14:11:27,793 - INFO - Stability -917.0: Accuracy = 1.0
# 2024-09-24 14:11:27,794 - INFO - Stability -910.5: Accuracy = 1.0
# 2024-09-24 14:11:27,795 - INFO - Stability -907.0: Accuracy = 1.0
# 2024-09-24 14:11:27,796 - INFO - Stability -904.5: Accuracy = 0.0
# 2024-09-24 14:11:27,797 - INFO - Stability -904.0: Accuracy = 0.0
# 2024-09-24 14:11:27,799 - INFO - Stability -900.0: Accuracy = 1.0
# 2024-09-24 14:11:27,800 - INFO - Stability -893.5: Accuracy = 1.0
# 2024-09-24 14:11:27,801 - INFO - Stability -891.5: Accuracy = 0.0
# 2024-09-24 14:11:27,803 - INFO - Stability -890.5: Accuracy = 1.0
# 2024-09-24 14:11:27,804 - INFO - Stability -887.5: Accuracy = 1.0
# 2024-09-24 14:11:27,805 - INFO - Stability -886.5: Accuracy = 1.0
# 2024-09-24 14:11:27,806 - INFO - Stability -881.0: Accuracy = 1.0
# 2024-09-24 14:11:27,807 - INFO - Stability -878.5: Accuracy = 1.0
# 2024-09-24 14:11:27,808 - INFO - Stability -877.5: Accuracy = 1.0
# 2024-09-24 14:11:27,809 - INFO - Stability -875.5: Accuracy = 0.0
# 2024-09-24 14:11:27,810 - INFO - Stability -874.0: Accuracy = 0.0
# 2024-09-24 14:11:27,811 - INFO - Stability -873.5: Accuracy = 1.0
# 2024-09-24 14:11:27,812 - INFO - Stability -866.5: Accuracy = 1.0
# 2024-09-24 14:11:27,814 - INFO - Stability -861.5: Accuracy = 1.0
# 2024-09-24 14:11:27,815 - INFO - Stability -859.0: Accuracy = 1.0
# 2024-09-24 14:11:27,816 - INFO - Stability -858.5: Accuracy = 1.0
# 2024-09-24 14:11:27,816 - INFO - Stability -856.5: Accuracy = 1.0
# 2024-09-24 14:11:27,817 - INFO - Stability -855.5: Accuracy = 1.0
# 2024-09-24 14:11:27,820 - INFO - Stability -853.0: Accuracy = 1.0
# 2024-09-24 14:11:27,821 - INFO - Stability -852.5: Accuracy = 1.0
# 2024-09-24 14:11:27,822 - INFO - Stability -852.0: Accuracy = 1.0
# 2024-09-24 14:11:27,823 - INFO - Stability -851.0: Accuracy = 1.0
# 2024-09-24 14:11:27,824 - INFO - Stability -848.5: Accuracy = 1.0
# 2024-09-24 14:11:27,825 - INFO - Stability -845.5: Accuracy = 1.0
# 2024-09-24 14:11:27,826 - INFO - Stability -844.5: Accuracy = 0.0
# 2024-09-24 14:11:27,827 - INFO - Stability -842.0: Accuracy = 1.0
# 2024-09-24 14:11:27,828 - INFO - Stability -836.5: Accuracy = 1.0
# 2024-09-24 14:11:27,830 - INFO - Stability -833.5: Accuracy = 1.0
# 2024-09-24 14:11:27,832 - INFO - Stability -832.0: Accuracy = 1.0
# 2024-09-24 14:11:27,833 - INFO - Stability -829.5: Accuracy = 1.0
# 2024-09-24 14:11:27,834 - INFO - Stability -828.5: Accuracy = 1.0
# 2024-09-24 14:11:27,835 - INFO - Stability -824.0: Accuracy = 1.0
# 2024-09-24 14:11:27,836 - INFO - Stability -822.5: Accuracy = 1.0
# 2024-09-24 14:11:27,836 - INFO - Stability -820.5: Accuracy = 1.0
# 2024-09-24 14:11:27,838 - INFO - Stability -818.5: Accuracy = 1.0
# 2024-09-24 14:11:27,839 - INFO - Stability -806.0: Accuracy = 1.0
# 2024-09-24 14:11:27,840 - INFO - Stability -805.0: Accuracy = 1.0
# 2024-09-24 14:11:27,841 - INFO - Stability -804.5: Accuracy = 1.0
# 2024-09-24 14:11:27,841 - INFO - Stability -804.0: Accuracy = 0.0
# 2024-09-24 14:11:27,843 - INFO - Stability -803.5: Accuracy = 1.0
# 2024-09-24 14:11:27,844 - INFO - Stability -802.0: Accuracy = 1.0
# 2024-09-24 14:11:27,845 - INFO - Stability -800.5: Accuracy = 1.0
# 2024-09-24 14:11:27,846 - INFO - Stability -791.0: Accuracy = 1.0
# 2024-09-24 14:11:27,847 - INFO - Stability -790.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:27,850 - INFO - Stability -787.0: Accuracy = 0.5
# 2024-09-24 14:11:27,851 - INFO - Stability -786.5: Accuracy = 1.0
# 2024-09-24 14:11:27,852 - INFO - Stability -781.5: Accuracy = 1.0
# 2024-09-24 14:11:27,853 - INFO - Stability -780.0: Accuracy = 1.0
# 2024-09-24 14:11:27,854 - INFO - Stability -778.5: Accuracy = 1.0
# 2024-09-24 14:11:27,855 - INFO - Stability -774.5: Accuracy = 1.0
# 2024-09-24 14:11:27,856 - INFO - Stability -774.0: Accuracy = 1.0
# 2024-09-24 14:11:27,857 - INFO - Stability -772.0: Accuracy = 1.0
# 2024-09-24 14:11:27,860 - INFO - Stability -766.5: Accuracy = 1.0
# 2024-09-24 14:11:27,862 - INFO - Stability -759.0: Accuracy = 1.0
# 2024-09-24 14:11:27,863 - INFO - Stability -756.0: Accuracy = 1.0
# 2024-09-24 14:11:27,864 - INFO - Stability -748.0: Accuracy = 1.0
# 2024-09-24 14:11:27,865 - INFO - Stability -744.5: Accuracy = 1.0
# 2024-09-24 14:11:27,866 - INFO - Stability -744.0: Accuracy = 1.0
# 2024-09-24 14:11:27,867 - INFO - Stability -741.5: Accuracy = 1.0
# 2024-09-24 14:11:27,869 - INFO - Stability -741.0: Accuracy = 1.0
# 2024-09-24 14:11:27,870 - INFO - Stability -740.5: Accuracy = 1.0
# 2024-09-24 14:11:27,871 - INFO - Stability -738.5: Accuracy = 1.0
# 2024-09-24 14:11:27,873 - INFO - Stability -735.5: Accuracy = 1.0
# 2024-09-24 14:11:27,874 - INFO - Stability -734.5: Accuracy = 1.0
# 2024-09-24 14:11:27,874 - INFO - Stability -734.0: Accuracy = 1.0
# 2024-09-24 14:11:27,876 - INFO - Stability -733.5: Accuracy = 1.0
# 2024-09-24 14:11:27,877 - INFO - Stability -723.0: Accuracy = 1.0
# 2024-09-24 14:11:27,878 - INFO - Stability -720.0: Accuracy = 1.0
# 2024-09-24 14:11:27,879 - INFO - Stability -719.5: Accuracy = 1.0
# 2024-09-24 14:11:27,880 - INFO - Stability -717.5: Accuracy = 1.0
# 2024-09-24 14:11:27,882 - INFO - Stability -715.5: Accuracy = 1.0
# 2024-09-24 14:11:27,883 - INFO - Stability -712.0: Accuracy = 1.0
# 2024-09-24 14:11:27,884 - INFO - Stability -708.5: Accuracy = 1.0
# 2024-09-24 14:11:27,885 - INFO - Stability -702.0: Accuracy = 1.0
# 2024-09-24 14:11:27,886 - INFO - Stability -701.5: Accuracy = 1.0
# 2024-09-24 14:11:27,886 - INFO - Stability -700.0: Accuracy = 1.0
# 2024-09-24 14:11:27,887 - INFO - Stability -694.0: Accuracy = 1.0
# 2024-09-24 14:11:27,888 - INFO - Stability -693.5: Accuracy = 1.0
# 2024-09-24 14:11:27,889 - INFO - Stability -691.5: Accuracy = 1.0
# 2024-09-24 14:11:27,890 - INFO - Stability -689.0: Accuracy = 1.0
# 2024-09-24 14:11:27,891 - INFO - Stability -688.0: Accuracy = 1.0
# 2024-09-24 14:11:27,892 - INFO - Stability -682.5: Accuracy = 1.0
# 2024-09-24 14:11:27,893 - INFO - Stability -678.0: Accuracy = 1.0
# 2024-09-24 14:11:27,894 - INFO - Stability -674.5: Accuracy = 1.0
# 2024-09-24 14:11:27,900 - INFO - Stability -673.5: Accuracy = 1.0
# 2024-09-24 14:11:27,901 - INFO - Stability -672.5: Accuracy = 1.0
# 2024-09-24 14:11:27,903 - INFO - Stability -670.0: Accuracy = 1.0
# 2024-09-24 14:11:27,904 - INFO - Stability -669.5: Accuracy = 1.0
# 2024-09-24 14:11:27,905 - INFO - Stability -664.5: Accuracy = 1.0
# 2024-09-24 14:11:27,906 - INFO - Stability -662.0: Accuracy = 1.0
# 2024-09-24 14:11:27,909 - INFO - Stability -660.5: Accuracy = 1.0
# 2024-09-24 14:11:27,910 - INFO - Stability -655.5: Accuracy = 1.0
# 2024-09-24 14:11:27,911 - INFO - Stability -654.5: Accuracy = 1.0
# 2024-09-24 14:11:27,911 - INFO - Stability -653.5: Accuracy = 1.0
# 2024-09-24 14:11:27,914 - INFO - Stability -649.5: Accuracy = 1.0
# 2024-09-24 14:11:27,915 - INFO - Stability -645.5: Accuracy = 1.0
# 2024-09-24 14:11:27,916 - INFO - Stability -644.5: Accuracy = 1.0
# 2024-09-24 14:11:27,917 - INFO - Stability -644.0: Accuracy = 1.0
# 2024-09-24 14:11:27,918 - INFO - Stability -643.0: Accuracy = 1.0
# 2024-09-24 14:11:27,918 - INFO - Stability -640.0: Accuracy = 1.0
# 2024-09-24 14:11:27,921 - INFO - Stability -639.5: Accuracy = 1.0
# 2024-09-24 14:11:27,922 - INFO - Stability -639.0: Accuracy = 1.0
# 2024-09-24 14:11:27,923 - INFO - Stability -638.0: Accuracy = 1.0
# 2024-09-24 14:11:27,924 - INFO - Stability -635.5: Accuracy = 1.0
# 2024-09-24 14:11:27,925 - INFO - Stability -635.0: Accuracy = 1.0
# 2024-09-24 14:11:27,927 - INFO - Stability -634.0: Accuracy = 1.0
# 2024-09-24 14:11:27,930 - INFO - Stability -633.5: Accuracy = 1.0
# 2024-09-24 14:11:27,930 - INFO - Stability -632.5: Accuracy = 1.0
# 2024-09-24 14:11:27,931 - INFO - Stability -625.5: Accuracy = 1.0
# 2024-09-24 14:11:27,933 - INFO - Stability -624.0: Accuracy = 1.0
# 2024-09-24 14:11:27,934 - INFO - Stability -621.5: Accuracy = 1.0
# 2024-09-24 14:11:27,935 - INFO - Stability -621.0: Accuracy = 1.0
# 2024-09-24 14:11:27,936 - INFO - Stability -619.0: Accuracy = 1.0
# 2024-09-24 14:11:27,937 - INFO - Stability -615.5: Accuracy = 1.0
# 2024-09-24 14:11:27,938 - INFO - Stability -613.0: Accuracy = 1.0
# 2024-09-24 14:11:27,940 - INFO - Stability -612.5: Accuracy = 1.0
# 2024-09-24 14:11:27,940 - INFO - Stability -611.0: Accuracy = 1.0
# 2024-09-24 14:11:27,941 - INFO - Stability -608.5: Accuracy = 1.0
# 2024-09-24 14:11:27,942 - INFO - Stability -608.0: Accuracy = 1.0
# 2024-09-24 14:11:27,943 - INFO - Stability -607.5: Accuracy = 1.0
# 2024-09-24 14:11:27,944 - INFO - Stability -603.5: Accuracy = 1.0
# 2024-09-24 14:11:27,945 - INFO - Stability -600.5: Accuracy = 1.0
# 2024-09-24 14:11:27,946 - INFO - Stability -597.0: Accuracy = 0.0
# 2024-09-24 14:11:27,946 - INFO - Stability -595.5: Accuracy = 1.0
# 2024-09-24 14:11:27,948 - INFO - Stability -593.5: Accuracy = 0.0
# 2024-09-24 14:11:27,950 - INFO - Stability -592.5: Accuracy = 0.5
# 2024-09-24 14:11:27,950 - INFO - Stability -591.0: Accuracy = 0.0
# 2024-09-24 14:11:27,951 - INFO - Stability -590.5: Accuracy = 1.0
# 2024-09-24 14:11:27,952 - INFO - Stability -589.0: Accuracy = 1.0
# 2024-09-24 14:11:27,953 - INFO - Stability -583.0: Accuracy = 1.0
# 2024-09-24 14:11:27,954 - INFO - Stability -582.5: Accuracy = 1.0
# 2024-09-24 14:11:27,955 - INFO - Stability -581.5: Accuracy = 1.0
# 2024-09-24 14:11:27,956 - INFO - Stability -573.5: Accuracy = 1.0
# 2024-09-24 14:11:27,957 - INFO - Stability -570.0: Accuracy = 1.0
# 2024-09-24 14:11:27,958 - INFO - Stability -569.0: Accuracy = 1.0
# 2024-09-24 14:11:27,959 - INFO - Stability -567.5: Accuracy = 1.0
# 2024-09-24 14:11:27,960 - INFO - Stability -564.5: Accuracy = 0.0
# 2024-09-24 14:11:27,963 - INFO - Stability -564.0: Accuracy = 1.0
# 2024-09-24 14:11:27,963 - INFO - Stability -563.5: Accuracy = 1.0
# 2024-09-24 14:11:27,964 - INFO - Stability -560.0: Accuracy = 1.0
# 2024-09-24 14:11:27,965 - INFO - Stability -559.5: Accuracy = 0.0
# 2024-09-24 14:11:27,968 - INFO - Stability -554.5: Accuracy = 1.0
# 2024-09-24 14:11:27,969 - INFO - Stability -551.5: Accuracy = 1.0
# 2024-09-24 14:11:27,969 - INFO - Stability -545.0: Accuracy = 1.0
# 2024-09-24 14:11:27,972 - INFO - Stability -544.0: Accuracy = 0.5
# 2024-09-24 14:11:27,973 - INFO - Stability -541.5: Accuracy = 1.0
# 2024-09-24 14:11:27,974 - INFO - Stability -530.5: Accuracy = 1.0
# 2024-09-24 14:11:27,975 - INFO - Stability -528.0: Accuracy = 1.0
# 2024-09-24 14:11:27,976 - INFO - Stability -525.5: Accuracy = 1.0
# 2024-09-24 14:11:27,977 - INFO - Stability -525.0: Accuracy = 1.0
# 2024-09-24 14:11:27,978 - INFO - Stability -523.5: Accuracy = 1.0
# 2024-09-24 14:11:27,979 - INFO - Stability -523.0: Accuracy = 1.0
# 2024-09-24 14:11:27,980 - INFO - Stability -521.0: Accuracy = 1.0
# 2024-09-24 14:11:27,981 - INFO - Stability -519.5: Accuracy = 1.0
# 2024-09-24 14:11:27,981 - INFO - Stability -516.5: Accuracy = 1.0
# 2024-09-24 14:11:27,985 - INFO - Stability -512.5: Accuracy = 1.0
# 2024-09-24 14:11:27,987 - INFO - Stability -511.0: Accuracy = 1.0
# 2024-09-24 14:11:27,988 - INFO - Stability -510.0: Accuracy = 1.0
# 2024-09-24 14:11:27,989 - INFO - Stability -509.0: Accuracy = 1.0
# 2024-09-24 14:11:27,990 - INFO - Stability -503.5: Accuracy = 0.0
# 2024-09-24 14:11:27,992 - INFO - Stability -500.5: Accuracy = 1.0
# 2024-09-24 14:11:27,993 - INFO - Stability -496.0: Accuracy = 1.0
# 2024-09-24 14:11:27,994 - INFO - Stability -495.0: Accuracy = 1.0
# 2024-09-24 14:11:27,994 - INFO - Stability -493.5: Accuracy = 1.0
# 2024-09-24 14:11:27,995 - INFO - Stability -486.0: Accuracy = 1.0
# 2024-09-24 14:11:27,996 - INFO - Stability -484.0: Accuracy = 1.0
# 2024-09-24 14:11:27,997 - INFO - Stability -483.0: Accuracy = 1.0
# 2024-09-24 14:11:27,998 - INFO - Stability -480.0: Accuracy = 1.0
# 2024-09-24 14:11:27,999 - INFO - Stability -475.5: Accuracy = 1.0
# 2024-09-24 14:11:27,999 - INFO - Stability -472.5: Accuracy = 1.0
# 2024-09-24 14:11:28,000 - INFO - Stability -471.5: Accuracy = 1.0
# 2024-09-24 14:11:28,001 - INFO - Stability -468.0: Accuracy = 1.0
# 2024-09-24 14:11:28,002 - INFO - Stability -465.5: Accuracy = 1.0
# 2024-09-24 14:11:28,003 - INFO - Stability -459.0: Accuracy = 1.0
# 2024-09-24 14:11:28,004 - INFO - Stability -457.5: Accuracy = 1.0
# 2024-09-24 14:11:28,005 - INFO - Stability -454.5: Accuracy = 1.0
# 2024-09-24 14:11:28,006 - INFO - Stability -453.0: Accuracy = 1.0
# 2024-09-24 14:11:28,006 - INFO - Stability -452.0: Accuracy = 1.0
# 2024-09-24 14:11:28,007 - INFO - Stability -450.0: Accuracy = 0.0
# 2024-09-24 14:11:28,008 - INFO - Stability -449.5: Accuracy = 1.0
# 2024-09-24 14:11:28,009 - INFO - Stability -449.0: Accuracy = 1.0
# 2024-09-24 14:11:28,009 - INFO - Stability -445.5: Accuracy = 1.0
# 2024-09-24 14:11:28,010 - INFO - Stability -445.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:28,014 - INFO - Stability -444.5: Accuracy = 0.5
# 2024-09-24 14:11:28,014 - INFO - Stability -443.5: Accuracy = 1.0
# 2024-09-24 14:11:28,015 - INFO - Stability -441.5: Accuracy = 1.0
# 2024-09-24 14:11:28,016 - INFO - Stability -440.5: Accuracy = 1.0
# 2024-09-24 14:11:28,017 - INFO - Stability -439.5: Accuracy = 1.0
# 2024-09-24 14:11:28,019 - INFO - Stability -436.5: Accuracy = 1.0
# 2024-09-24 14:11:28,021 - INFO - Stability -435.5: Accuracy = 1.0
# 2024-09-24 14:11:28,021 - INFO - Stability -434.5: Accuracy = 1.0
# 2024-09-24 14:11:28,024 - INFO - Stability -431.0: Accuracy = 1.0
# 2024-09-24 14:11:28,025 - INFO - Stability -429.0: Accuracy = 1.0
# 2024-09-24 14:11:28,025 - INFO - Stability -428.5: Accuracy = 1.0
# 2024-09-24 14:11:28,027 - INFO - Stability -427.0: Accuracy = 1.0
# 2024-09-24 14:11:28,028 - INFO - Stability -426.0: Accuracy = 1.0
# 2024-09-24 14:11:28,029 - INFO - Stability -422.0: Accuracy = 1.0
# 2024-09-24 14:11:28,030 - INFO - Stability -416.5: Accuracy = 1.0
# 2024-09-24 14:11:28,031 - INFO - Stability -415.5: Accuracy = 0.0
# 2024-09-24 14:11:28,032 - INFO - Stability -415.0: Accuracy = 1.0
# 2024-09-24 14:11:28,035 - INFO - Stability -410.5: Accuracy = 1.0
# 2024-09-24 14:11:28,036 - INFO - Stability -407.5: Accuracy = 1.0
# 2024-09-24 14:11:28,036 - INFO - Stability -405.0: Accuracy = 0.0
# 2024-09-24 14:11:28,038 - INFO - Stability -403.5: Accuracy = 1.0
# 2024-09-24 14:11:28,039 - INFO - Stability -402.0: Accuracy = 1.0
# 2024-09-24 14:11:28,040 - INFO - Stability -396.5: Accuracy = 1.0
# 2024-09-24 14:11:28,040 - INFO - Stability -393.0: Accuracy = 1.0
# 2024-09-24 14:11:28,041 - INFO - Stability -392.5: Accuracy = 1.0
# 2024-09-24 14:11:28,042 - INFO - Stability -391.5: Accuracy = 1.0
# 2024-09-24 14:11:28,043 - INFO - Stability -390.0: Accuracy = 1.0
# 2024-09-24 14:11:28,044 - INFO - Stability -386.5: Accuracy = 1.0
# 2024-09-24 14:11:28,045 - INFO - Stability -382.5: Accuracy = 0.5
# 2024-09-24 14:11:28,047 - INFO - Stability -376.5: Accuracy = 1.0
# 2024-09-24 14:11:28,047 - INFO - Stability -375.0: Accuracy = 1.0
# 2024-09-24 14:11:28,048 - INFO - Stability -372.0: Accuracy = 1.0
# 2024-09-24 14:11:28,049 - INFO - Stability -370.0: Accuracy = 1.0
# 2024-09-24 14:11:28,049 - INFO - Stability -366.0: Accuracy = 1.0
# 2024-09-24 14:11:28,051 - INFO - Stability -363.5: Accuracy = 1.0
# 2024-09-24 14:11:28,052 - INFO - Stability -363.0: Accuracy = 1.0
# 2024-09-24 14:11:28,052 - INFO - Stability -361.5: Accuracy = 0.0
# 2024-09-24 14:11:28,053 - INFO - Stability -359.0: Accuracy = 1.0
# 2024-09-24 14:11:28,054 - INFO - Stability -358.0: Accuracy = 1.0
# 2024-09-24 14:11:28,055 - INFO - Stability -355.5: Accuracy = 1.0
# 2024-09-24 14:11:28,056 - INFO - Stability -355.0: Accuracy = 1.0
# 2024-09-24 14:11:28,057 - INFO - Stability -354.5: Accuracy = 1.0
# 2024-09-24 14:11:28,058 - INFO - Stability -353.0: Accuracy = 1.0
# 2024-09-24 14:11:28,060 - INFO - Stability -352.5: Accuracy = 1.0
# 2024-09-24 14:11:28,061 - INFO - Stability -352.0: Accuracy = 1.0
# 2024-09-24 14:11:28,062 - INFO - Stability -348.0: Accuracy = 1.0
# 2024-09-24 14:11:28,063 - INFO - Stability -346.5: Accuracy = 1.0
# 2024-09-24 14:11:28,064 - INFO - Stability -344.0: Accuracy = 1.0
# 2024-09-24 14:11:28,066 - INFO - Stability -343.0: Accuracy = 1.0
# 2024-09-24 14:11:28,067 - INFO - Stability -340.5: Accuracy = 1.0
# 2024-09-24 14:11:28,068 - INFO - Stability -338.5: Accuracy = 1.0
# 2024-09-24 14:11:28,069 - INFO - Stability -336.0: Accuracy = 1.0
# 2024-09-24 14:11:28,070 - INFO - Stability -333.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:28,073 - INFO - Stability -332.0: Accuracy = 0.5
# 2024-09-24 14:11:28,074 - INFO - Stability -330.5: Accuracy = 1.0
# 2024-09-24 14:11:28,077 - INFO - Stability -330.0: Accuracy = 1.0
# 2024-09-24 14:11:28,078 - INFO - Stability -329.5: Accuracy = 1.0
# 2024-09-24 14:11:28,079 - INFO - Stability -327.5: Accuracy = 1.0
# 2024-09-24 14:11:28,080 - INFO - Stability -326.5: Accuracy = 1.0
# 2024-09-24 14:11:28,081 - INFO - Stability -324.5: Accuracy = 1.0
# 2024-09-24 14:11:28,082 - INFO - Stability -324.0: Accuracy = 1.0
# 2024-09-24 14:11:28,083 - INFO - Stability -321.0: Accuracy = 1.0
# 2024-09-24 14:11:28,084 - INFO - Stability -320.5: Accuracy = 1.0
# 2024-09-24 14:11:28,085 - INFO - Stability -319.5: Accuracy = 1.0
# 2024-09-24 14:11:28,085 - INFO - Stability -318.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:28,089 - INFO - Stability -315.5: Accuracy = 0.6666666666666666
# 2024-09-24 14:11:28,090 - INFO - Stability -315.0: Accuracy = 1.0
# 2024-09-24 14:11:28,091 - INFO - Stability -314.5: Accuracy = 1.0
# 2024-09-24 14:11:28,092 - INFO - Stability -313.0: Accuracy = 1.0
# 2024-09-24 14:11:28,094 - INFO - Stability -312.0: Accuracy = 1.0
# 2024-09-24 14:11:28,095 - INFO - Stability -306.5: Accuracy = 1.0
# 2024-09-24 14:11:28,097 - INFO - Stability -302.5: Accuracy = 1.0
# 2024-09-24 14:11:28,098 - INFO - Stability -301.0: Accuracy = 1.0
# 2024-09-24 14:11:28,099 - INFO - Stability -300.0: Accuracy = 1.0
# 2024-09-24 14:11:28,100 - INFO - Stability -297.0: Accuracy = 1.0
# 2024-09-24 14:11:28,101 - INFO - Stability -295.0: Accuracy = 1.0
# 2024-09-24 14:11:28,101 - INFO - Stability -294.0: Accuracy = 1.0
# 2024-09-24 14:11:28,102 - INFO - Stability -293.0: Accuracy = 1.0
# 2024-09-24 14:11:28,103 - INFO - Stability -288.5: Accuracy = 1.0
# 2024-09-24 14:11:28,104 - INFO - Stability -288.0: Accuracy = 1.0
# 2024-09-24 14:11:28,105 - INFO - Stability -286.5: Accuracy = 1.0
# 2024-09-24 14:11:28,106 - INFO - Stability -285.0: Accuracy = 1.0
# 2024-09-24 14:11:28,107 - INFO - Stability -284.0: Accuracy = 1.0
# 2024-09-24 14:11:28,108 - INFO - Stability -278.0: Accuracy = 1.0
# 2024-09-24 14:11:28,109 - INFO - Stability -277.5: Accuracy = 1.0
# 2024-09-24 14:11:28,110 - INFO - Stability -275.0: Accuracy = 1.0
# 2024-09-24 14:11:28,110 - INFO - Stability -270.5: Accuracy = 1.0
# 2024-09-24 14:11:28,111 - INFO - Stability -267.0: Accuracy = 1.0
# 2024-09-24 14:11:28,112 - INFO - Stability -263.0: Accuracy = 1.0
# 2024-09-24 14:11:28,113 - INFO - Stability -262.5: Accuracy = 0.0
# 2024-09-24 14:11:28,116 - INFO - Stability -261.0: Accuracy = 1.0
# 2024-09-24 14:11:28,117 - INFO - Stability -259.5: Accuracy = 1.0
# 2024-09-24 14:11:28,118 - INFO - Stability -258.0: Accuracy = 0.5
# 2024-09-24 14:11:28,120 - INFO - Stability -257.0: Accuracy = 1.0
# 2024-09-24 14:11:28,121 - INFO - Stability -254.5: Accuracy = 1.0
# 2024-09-24 14:11:28,123 - INFO - Stability -251.5: Accuracy = 1.0
# 2024-09-24 14:11:28,125 - INFO - Stability -250.5: Accuracy = 1.0
# 2024-09-24 14:11:28,126 - INFO - Stability -249.5: Accuracy = 1.0
# 2024-09-24 14:11:28,127 - INFO - Stability -248.5: Accuracy = 1.0
# 2024-09-24 14:11:28,128 - INFO - Stability -246.0: Accuracy = 1.0
# 2024-09-24 14:11:28,129 - INFO - Stability -245.0: Accuracy = 1.0
# 2024-09-24 14:11:28,131 - INFO - Stability -240.5: Accuracy = 1.0
# 2024-09-24 14:11:28,132 - INFO - Stability -239.0: Accuracy = 1.0
# 2024-09-24 14:11:28,133 - INFO - Stability -237.0: Accuracy = 1.0
# 2024-09-24 14:11:28,135 - INFO - Stability -235.0: Accuracy = 1.0
# 2024-09-24 14:11:28,135 - INFO - Stability -234.0: Accuracy = 1.0
# 2024-09-24 14:11:28,137 - INFO - Stability -233.0: Accuracy = 1.0
# 2024-09-24 14:11:28,139 - INFO - Stability -232.0: Accuracy = 1.0
# 2024-09-24 14:11:28,141 - INFO - Stability -231.0: Accuracy = 1.0
# 2024-09-24 14:11:28,142 - INFO - Stability -216.5: Accuracy = 1.0
# 2024-09-24 14:11:28,143 - INFO - Stability -214.0: Accuracy = 0.0
# 2024-09-24 14:11:28,145 - INFO - Stability -213.5: Accuracy = 1.0
# 2024-09-24 14:11:28,146 - INFO - Stability -213.0: Accuracy = 1.0
# 2024-09-24 14:11:28,148 - INFO - Stability -211.0: Accuracy = 1.0
# 2024-09-24 14:11:28,149 - INFO - Stability -210.0: Accuracy = 1.0
# 2024-09-24 14:11:28,150 - INFO - Stability -209.5: Accuracy = 1.0
# 2024-09-24 14:11:28,151 - INFO - Stability -207.5: Accuracy = 1.0
# 2024-09-24 14:11:28,152 - INFO - Stability -206.5: Accuracy = 1.0
# 2024-09-24 14:11:28,153 - INFO - Stability -203.0: Accuracy = 1.0
# 2024-09-24 14:11:28,154 - INFO - Stability -202.0: Accuracy = 1.0
# 2024-09-24 14:11:28,157 - INFO - Stability -201.0: Accuracy = 1.0
# 2024-09-24 14:11:28,158 - INFO - Stability -198.0: Accuracy = 1.0
# 2024-09-24 14:11:28,159 - INFO - Stability -195.0: Accuracy = 1.0
# 2024-09-24 14:11:28,160 - INFO - Stability -193.5: Accuracy = 1.0
# 2024-09-24 14:11:28,161 - INFO - Stability -190.5: Accuracy = 1.0
# 2024-09-24 14:11:28,163 - INFO - Stability -189.0: Accuracy = 1.0
# 2024-09-24 14:11:28,164 - INFO - Stability -188.5: Accuracy = 1.0
# 2024-09-24 14:11:28,165 - INFO - Stability -184.5: Accuracy = 1.0
# 2024-09-24 14:11:28,166 - INFO - Stability -181.5: Accuracy = 1.0
# 2024-09-24 14:11:28,166 - INFO - Stability -179.5: Accuracy = 1.0
# 2024-09-24 14:11:28,167 - INFO - Stability -179.0: Accuracy = 1.0
# 2024-09-24 14:11:28,168 - INFO - Stability -178.5: Accuracy = 1.0
# 2024-09-24 14:11:28,169 - INFO - Stability -174.0: Accuracy = 1.0
# 2024-09-24 14:11:28,170 - INFO - Stability -173.5: Accuracy = 1.0
# 2024-09-24 14:11:28,171 - INFO - Stability -170.5: Accuracy = 1.0
# 2024-09-24 14:11:28,171 - INFO - Stability -169.5: Accuracy = 1.0
# 2024-09-24 14:11:28,172 - INFO - Stability -168.5: Accuracy = 1.0
# 2024-09-24 14:11:28,173 - INFO - Stability -168.0: Accuracy = 1.0
# 2024-09-24 14:11:28,174 - INFO - Stability -167.5: Accuracy = 1.0
# 2024-09-24 14:11:28,174 - INFO - Stability -166.5: Accuracy = 1.0
# 2024-09-24 14:11:28,175 - INFO - Stability -163.0: Accuracy = 1.0
# 2024-09-24 14:11:28,179 - INFO - Stability -161.0: Accuracy = 0.5
# 2024-09-24 14:11:28,180 - INFO - Stability -158.0: Accuracy = 0.0
# 2024-09-24 14:11:28,181 - INFO - Stability -157.5: Accuracy = 1.0
# 2024-09-24 14:11:28,182 - INFO - Stability -156.5: Accuracy = 1.0
# 2024-09-24 14:11:28,183 - INFO - Stability -155.5: Accuracy = 1.0
# 2024-09-24 14:11:28,184 - INFO - Stability -155.0: Accuracy = 1.0
# 2024-09-24 14:11:28,185 - INFO - Stability -153.5: Accuracy = 1.0
# 2024-09-24 14:11:28,186 - INFO - Stability -151.5: Accuracy = 1.0
# 2024-09-24 14:11:28,187 - INFO - Stability -147.0: Accuracy = 1.0
# 2024-09-24 14:11:28,188 - INFO - Stability -146.5: Accuracy = 1.0
# 2024-09-24 14:11:28,189 - INFO - Stability -143.0: Accuracy = 1.0
# 2024-09-24 14:11:28,190 - INFO - Stability -141.0: Accuracy = 1.0
# 2024-09-24 14:11:28,191 - INFO - Stability -140.5: Accuracy = 1.0
# 2024-09-24 14:11:28,192 - INFO - Stability -139.5: Accuracy = 1.0
# 2024-09-24 14:11:28,193 - INFO - Stability -136.0: Accuracy = 1.0
# 2024-09-24 14:11:28,194 - INFO - Stability -135.5: Accuracy = 1.0
# 2024-09-24 14:11:28,194 - INFO - Stability -133.5: Accuracy = 1.0
# 2024-09-24 14:11:28,195 - INFO - Stability -129.0: Accuracy = 1.0
# 2024-09-24 14:11:28,196 - INFO - Stability -128.0: Accuracy = 1.0
# 2024-09-24 14:11:28,199 - INFO - Stability -126.5: Accuracy = 1.0
# 2024-09-24 14:11:28,200 - INFO - Stability -124.0: Accuracy = 1.0
# 2024-09-24 14:11:28,201 - INFO - Stability -121.0: Accuracy = 1.0
# 2024-09-24 14:11:28,201 - INFO - Stability -115.0: Accuracy = 1.0
# 2024-09-24 14:11:28,203 - INFO - Stability -111.0: Accuracy = 1.0
# 2024-09-24 14:11:28,205 - INFO - Stability -109.0: Accuracy = 1.0
# 2024-09-24 14:11:28,206 - INFO - Stability -108.0: Accuracy = 1.0
# 2024-09-24 14:11:28,207 - INFO - Stability -107.5: Accuracy = 1.0
# 2024-09-24 14:11:28,208 - INFO - Stability -104.5: Accuracy = 1.0
# 2024-09-24 14:11:28,209 - INFO - Stability -97.5: Accuracy = 1.0
# 2024-09-24 14:11:28,210 - INFO - Stability -94.0: Accuracy = 1.0
# 2024-09-24 14:11:28,211 - INFO - Stability -92.5: Accuracy = 1.0
# 2024-09-24 14:11:28,213 - INFO - Stability -91.0: Accuracy = 1.0
# 2024-09-24 14:11:28,214 - INFO - Stability -89.5: Accuracy = 1.0
# 2024-09-24 14:11:28,215 - INFO - Stability -89.0: Accuracy = 1.0
# 2024-09-24 14:11:28,216 - INFO - Stability -86.0: Accuracy = 1.0
# 2024-09-24 14:11:28,217 - INFO - Stability -85.0: Accuracy = 1.0
# 2024-09-24 14:11:28,218 - INFO - Stability -84.0: Accuracy = 1.0
# 2024-09-24 14:11:28,220 - INFO - Stability -82.5: Accuracy = 1.0
# 2024-09-24 14:11:28,221 - INFO - Stability -78.0: Accuracy = 1.0
# 2024-09-24 14:11:28,222 - INFO - Stability -77.5: Accuracy = 1.0
# 2024-09-24 14:11:28,224 - INFO - Stability -76.5: Accuracy = 1.0
# 2024-09-24 14:11:28,225 - INFO - Stability -73.0: Accuracy = 1.0
# 2024-09-24 14:11:28,227 - INFO - Stability -72.5: Accuracy = 1.0
# 2024-09-24 14:11:28,227 - INFO - Stability -69.0: Accuracy = 1.0
# 2024-09-24 14:11:28,228 - INFO - Stability -66.0: Accuracy = 1.0
# 2024-09-24 14:11:28,230 - INFO - Stability -63.0: Accuracy = 1.0
# 2024-09-24 14:11:28,230 - INFO - Stability -62.0: Accuracy = 1.0
# 2024-09-24 14:11:28,231 - INFO - Stability -61.5: Accuracy = 0.0
# 2024-09-24 14:11:28,232 - INFO - Stability -60.0: Accuracy = 1.0
# 2024-09-24 14:11:28,233 - INFO - Stability -59.0: Accuracy = 1.0
# 2024-09-24 14:11:28,234 - INFO - Stability -58.0: Accuracy = 1.0
# 2024-09-24 14:11:28,235 - INFO - Stability -55.5: Accuracy = 1.0
# 2024-09-24 14:11:28,236 - INFO - Stability -55.0: Accuracy = 1.0
# 2024-09-24 14:11:28,237 - INFO - Stability -54.5: Accuracy = 1.0
# 2024-09-24 14:11:28,238 - INFO - Stability -50.5: Accuracy = 0.0
# 2024-09-24 14:11:28,239 - INFO - Stability -49.5: Accuracy = 1.0
# 2024-09-24 14:11:28,240 - INFO - Stability -47.5: Accuracy = 1.0
# 2024-09-24 14:11:28,241 - INFO - Stability -46.0: Accuracy = 1.0
# 2024-09-24 14:11:28,241 - INFO - Stability -45.5: Accuracy = 0.0
# 2024-09-24 14:11:28,242 - INFO - Stability -45.0: Accuracy = 1.0
# 2024-09-24 14:11:28,243 - INFO - Stability -44.5: Accuracy = 1.0
# 2024-09-24 14:11:28,244 - INFO - Stability -43.5: Accuracy = 1.0
# 2024-09-24 14:11:28,245 - INFO - Stability -42.5: Accuracy = 1.0
# 2024-09-24 14:11:28,246 - INFO - Stability -41.5: Accuracy = 1.0
# 2024-09-24 14:11:28,247 - INFO - Stability -40.5: Accuracy = 1.0
# 2024-09-24 14:11:28,249 - INFO - Stability -40.0: Accuracy = 1.0
# 2024-09-24 14:11:28,250 - INFO - Stability -38.0: Accuracy = 1.0
# 2024-09-24 14:11:28,251 - INFO - Stability -37.5: Accuracy = 1.0
# 2024-09-24 14:11:28,253 - INFO - Stability -32.5: Accuracy = 1.0
# 2024-09-24 14:11:28,254 - INFO - Stability -31.0: Accuracy = 1.0
# 2024-09-24 14:11:28,255 - INFO - Stability -28.5: Accuracy = 1.0
# 2024-09-24 14:11:28,257 - INFO - Stability -28.0: Accuracy = 1.0
# 2024-09-24 14:11:28,258 - INFO - Stability -27.5: Accuracy = 1.0
# 2024-09-24 14:11:28,259 - INFO - Stability -22.5: Accuracy = 1.0
# 2024-09-24 14:11:28,260 - INFO - Stability -21.0: Accuracy = 1.0
# 2024-09-24 14:11:28,261 - INFO - Stability -19.5: Accuracy = 1.0
# 2024-09-24 14:11:28,262 - INFO - Stability -16.0: Accuracy = 1.0
# 2024-09-24 14:11:28,263 - INFO - Stability -15.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:28,266 - INFO - Stability -11.5: Accuracy = 0.5
# 2024-09-24 14:11:28,268 - INFO - Stability -11.0: Accuracy = 1.0
# 2024-09-24 14:11:28,269 - INFO - Stability -7.5: Accuracy = 1.0
# 2024-09-24 14:11:28,270 - INFO - Stability -2.0: Accuracy = 1.0
# 2024-09-24 14:11:28,271 - INFO - Stability 1.5: Accuracy = 1.0
# 2024-09-24 14:11:28,273 - INFO - Stability 2.5: Accuracy = 1.0
# 2024-09-24 14:11:28,274 - INFO - Stability 5.5: Accuracy = 1.0
# 2024-09-24 14:11:28,275 - INFO - Stability 6.5: Accuracy = 1.0
# 2024-09-24 14:11:28,276 - INFO - Stability 8.0: Accuracy = 1.0
# 2024-09-24 14:11:28,277 - INFO - Stability 9.5: Accuracy = 1.0
# 2024-09-24 14:11:28,278 - INFO - Stability 14.0: Accuracy = 1.0
# 2024-09-24 14:11:28,280 - INFO - Stability 18.5: Accuracy = 1.0
# 2024-09-24 14:11:28,281 - INFO - Stability 19.0: Accuracy = 1.0
# 2024-09-24 14:11:28,282 - INFO - Stability 20.0: Accuracy = 1.0
# 2024-09-24 14:11:28,283 - INFO - Stability 20.5: Accuracy = 1.0
# 2024-09-24 14:11:28,284 - INFO - Stability 21.0: Accuracy = 1.0
# ...
# 2024-09-24 14:11:30,204 - INFO - Stability 3179.5: Accuracy = 1.0
# 2024-09-24 14:11:30,206 - INFO - Stability 3182.5: Accuracy = 0.0
# 2024-09-24 14:11:30,206 - INFO - Stability 3183.5: Accuracy = 1.0
# 2024-09-24 14:11:30,207 - INFO - Stability 3184.0: Accuracy = 1.0
# 2024-09-24 14:11:30,208 - INFO - Stability 3185.5: Accuracy = 1.0
# 2024-09-24 14:11:30,208 - INFO - Stability 3187.5: Accuracy = 1.0
# 2024-09-24 14:11:30,210 - INFO - Stability 3188.0: Accuracy = 1.0
# 2024-09-24 14:11:30,211 - INFO - Stability 3191.5: Accuracy = 1.0
# 2024-09-24 14:11:30,212 - INFO - Stability 3192.0: Accuracy = 1.0
# 2024-09-24 14:11:30,213 - INFO - Stability 3193.5: Accuracy = 1.0
# 2024-09-24 14:11:30,213 - INFO - Stability 3195.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,217 - INFO - Stability 3198.0: Accuracy = 0.5
# 2024-09-24 14:11:30,219 - INFO - Stability 3199.0: Accuracy = 1.0
# 2024-09-24 14:11:30,220 - INFO - Stability 3200.0: Accuracy = 1.0
# 2024-09-24 14:11:30,221 - INFO - Stability 3201.0: Accuracy = 1.0
# 2024-09-24 14:11:30,222 - INFO - Stability 3202.0: Accuracy = 1.0
# 2024-09-24 14:11:30,223 - INFO - Stability 3205.5: Accuracy = 1.0
# 2024-09-24 14:11:30,224 - INFO - Stability 3208.0: Accuracy = 1.0
# 2024-09-24 14:11:30,226 - INFO - Stability 3211.0: Accuracy = 1.0
# 2024-09-24 14:11:30,227 - INFO - Stability 3217.5: Accuracy = 1.0
# 2024-09-24 14:11:30,228 - INFO - Stability 3218.5: Accuracy = 1.0
# 2024-09-24 14:11:30,229 - INFO - Stability 3219.0: Accuracy = 1.0
# 2024-09-24 14:11:30,230 - INFO - Stability 3220.5: Accuracy = 1.0
# 2024-09-24 14:11:30,231 - INFO - Stability 3223.0: Accuracy = 1.0
# 2024-09-24 14:11:30,231 - INFO - Stability 3225.5: Accuracy = 1.0
# 2024-09-24 14:11:30,233 - INFO - Stability 3231.0: Accuracy = 1.0
# 2024-09-24 14:11:30,234 - INFO - Stability 3231.5: Accuracy = 1.0
# 2024-09-24 14:11:30,235 - INFO - Stability 3232.5: Accuracy = 1.0
# 2024-09-24 14:11:30,236 - INFO - Stability 3234.0: Accuracy = 0.0
# 2024-09-24 14:11:30,237 - INFO - Stability 3236.5: Accuracy = 1.0
# 2024-09-24 14:11:30,238 - INFO - Stability 3240.5: Accuracy = 1.0
# 2024-09-24 14:11:30,238 - INFO - Stability 3245.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,241 - INFO - Stability 3248.5: Accuracy = 0.5
# 2024-09-24 14:11:30,242 - INFO - Stability 3249.0: Accuracy = 1.0
# 2024-09-24 14:11:30,243 - INFO - Stability 3251.0: Accuracy = 1.0
# 2024-09-24 14:11:30,244 - INFO - Stability 3251.5: Accuracy = 1.0
# 2024-09-24 14:11:30,244 - INFO - Stability 3256.0: Accuracy = 1.0
# 2024-09-24 14:11:30,245 - INFO - Stability 3258.0: Accuracy = 1.0
# 2024-09-24 14:11:30,247 - INFO - Stability 3258.5: Accuracy = 1.0
# 2024-09-24 14:11:30,247 - INFO - Stability 3262.0: Accuracy = 1.0
# 2024-09-24 14:11:30,248 - INFO - Stability 3262.5: Accuracy = 1.0
# 2024-09-24 14:11:30,249 - INFO - Stability 3263.5: Accuracy = 1.0
# 2024-09-24 14:11:30,250 - INFO - Stability 3264.0: Accuracy = 1.0
# 2024-09-24 14:11:30,251 - INFO - Stability 3266.5: Accuracy = 1.0
# 2024-09-24 14:11:30,252 - INFO - Stability 3270.0: Accuracy = 1.0
# 2024-09-24 14:11:30,253 - INFO - Stability 3271.0: Accuracy = 1.0
# 2024-09-24 14:11:30,254 - INFO - Stability 3271.5: Accuracy = 1.0
# 2024-09-24 14:11:30,255 - INFO - Stability 3273.0: Accuracy = 1.0
# 2024-09-24 14:11:30,256 - INFO - Stability 3274.0: Accuracy = 1.0
# 2024-09-24 14:11:30,257 - INFO - Stability 3274.5: Accuracy = 1.0
# 2024-09-24 14:11:30,258 - INFO - Stability 3277.0: Accuracy = 1.0
# 2024-09-24 14:11:30,258 - INFO - Stability 3279.0: Accuracy = 1.0
# 2024-09-24 14:11:30,259 - INFO - Stability 3280.0: Accuracy = 1.0
# 2024-09-24 14:11:30,260 - INFO - Stability 3281.0: Accuracy = 1.0
# 2024-09-24 14:11:30,261 - INFO - Stability 3282.0: Accuracy = 1.0
# 2024-09-24 14:11:30,262 - INFO - Stability 3284.5: Accuracy = 1.0
# 2024-09-24 14:11:30,262 - INFO - Stability 3290.0: Accuracy = 1.0
# 2024-09-24 14:11:30,263 - INFO - Stability 3292.5: Accuracy = 1.0
# 2024-09-24 14:11:30,264 - INFO - Stability 3294.0: Accuracy = 1.0
# 2024-09-24 14:11:30,267 - INFO - Stability 3295.5: Accuracy = 1.0
# 2024-09-24 14:11:30,268 - INFO - Stability 3296.5: Accuracy = 1.0
# 2024-09-24 14:11:30,269 - INFO - Stability 3304.0: Accuracy = 1.0
# 2024-09-24 14:11:30,272 - INFO - Stability 3307.5: Accuracy = 1.0
# 2024-09-24 14:11:30,273 - INFO - Stability 3311.0: Accuracy = 1.0
# 2024-09-24 14:11:30,273 - INFO - Stability 3314.0: Accuracy = 1.0
# 2024-09-24 14:11:30,274 - INFO - Stability 3316.0: Accuracy = 1.0
# 2024-09-24 14:11:30,275 - INFO - Stability 3317.5: Accuracy = 1.0
# 2024-09-24 14:11:30,278 - INFO - Stability 3321.5: Accuracy = 1.0
# 2024-09-24 14:11:30,279 - INFO - Stability 3323.0: Accuracy = 1.0
# 2024-09-24 14:11:30,280 - INFO - Stability 3325.5: Accuracy = 1.0
# 2024-09-24 14:11:30,281 - INFO - Stability 3326.0: Accuracy = 0.0
# 2024-09-24 14:11:30,284 - INFO - Stability 3327.5: Accuracy = 1.0
# 2024-09-24 14:11:30,285 - INFO - Stability 3329.0: Accuracy = 1.0
# 2024-09-24 14:11:30,286 - INFO - Stability 3330.0: Accuracy = 1.0
# 2024-09-24 14:11:30,287 - INFO - Stability 3330.5: Accuracy = 1.0
# 2024-09-24 14:11:30,288 - INFO - Stability 3331.5: Accuracy = 1.0
# 2024-09-24 14:11:30,289 - INFO - Stability 3333.5: Accuracy = 1.0
# 2024-09-24 14:11:30,291 - INFO - Stability 3334.0: Accuracy = 1.0
# 2024-09-24 14:11:30,293 - INFO - Stability 3341.0: Accuracy = 1.0
# 2024-09-24 14:11:30,293 - INFO - Stability 3341.5: Accuracy = 1.0
# 2024-09-24 14:11:30,294 - INFO - Stability 3342.0: Accuracy = 0.0
# 2024-09-24 14:11:30,295 - INFO - Stability 3342.5: Accuracy = 1.0
# 2024-09-24 14:11:30,296 - INFO - Stability 3345.0: Accuracy = 1.0
# 2024-09-24 14:11:30,299 - INFO - Stability 3347.0: Accuracy = 1.0
# 2024-09-24 14:11:30,300 - INFO - Stability 3348.0: Accuracy = 1.0
# 2024-09-24 14:11:30,302 - INFO - Stability 3349.5: Accuracy = 1.0
# 2024-09-24 14:11:30,304 - INFO - Stability 3350.0: Accuracy = 1.0
# 2024-09-24 14:11:30,305 - INFO - Stability 3351.0: Accuracy = 1.0
# 2024-09-24 14:11:30,307 - INFO - Stability 3353.0: Accuracy = 1.0
# 2024-09-24 14:11:30,307 - INFO - Stability 3354.0: Accuracy = 1.0
# 2024-09-24 14:11:30,309 - INFO - Stability 3357.5: Accuracy = 1.0
# 2024-09-24 14:11:30,310 - INFO - Stability 3358.5: Accuracy = 1.0
# 2024-09-24 14:11:30,311 - INFO - Stability 3360.5: Accuracy = 1.0
# 2024-09-24 14:11:30,313 - INFO - Stability 3361.5: Accuracy = 1.0
# 2024-09-24 14:11:30,313 - INFO - Stability 3362.0: Accuracy = 1.0
# 2024-09-24 14:11:30,315 - INFO - Stability 3362.5: Accuracy = 1.0
# 2024-09-24 14:11:30,317 - INFO - Stability 3363.0: Accuracy = 1.0
# 2024-09-24 14:11:30,318 - INFO - Stability 3364.0: Accuracy = 1.0
# 2024-09-24 14:11:30,319 - INFO - Stability 3365.0: Accuracy = 1.0
# 2024-09-24 14:11:30,319 - INFO - Stability 3366.5: Accuracy = 1.0
# 2024-09-24 14:11:30,321 - INFO - Stability 3368.5: Accuracy = 1.0
# 2024-09-24 14:11:30,322 - INFO - Stability 3371.0: Accuracy = 1.0
# 2024-09-24 14:11:30,323 - INFO - Stability 3374.0: Accuracy = 0.0
# 2024-09-24 14:11:30,324 - INFO - Stability 3375.5: Accuracy = 1.0
# 2024-09-24 14:11:30,325 - INFO - Stability 3376.0: Accuracy = 1.0
# 2024-09-24 14:11:30,326 - INFO - Stability 3378.0: Accuracy = 1.0
# 2024-09-24 14:11:30,327 - INFO - Stability 3379.5: Accuracy = 1.0
# 2024-09-24 14:11:30,328 - INFO - Stability 3381.0: Accuracy = 1.0
# 2024-09-24 14:11:30,329 - INFO - Stability 3381.5: Accuracy = 1.0
# 2024-09-24 14:11:30,329 - INFO - Stability 3382.0: Accuracy = 1.0
# 2024-09-24 14:11:30,330 - INFO - Stability 3382.5: Accuracy = 1.0
# 2024-09-24 14:11:30,331 - INFO - Stability 3384.0: Accuracy = 1.0
# 2024-09-24 14:11:30,332 - INFO - Stability 3384.5: Accuracy = 1.0
# 2024-09-24 14:11:30,332 - INFO - Stability 3386.0: Accuracy = 1.0
# 2024-09-24 14:11:30,333 - INFO - Stability 3387.0: Accuracy = 1.0
# 2024-09-24 14:11:30,334 - INFO - Stability 3387.5: Accuracy = 1.0
# 2024-09-24 14:11:30,335 - INFO - Stability 3388.5: Accuracy = 1.0
# 2024-09-24 14:11:30,338 - INFO - Stability 3389.5: Accuracy = 1.0
# 2024-09-24 14:11:30,339 - INFO - Stability 3392.0: Accuracy = 1.0
# 2024-09-24 14:11:30,340 - INFO - Stability 3394.5: Accuracy = 1.0
# 2024-09-24 14:11:30,340 - INFO - Stability 3396.5: Accuracy = 1.0
# 2024-09-24 14:11:30,343 - INFO - Stability 3398.0: Accuracy = 1.0
# 2024-09-24 14:11:30,344 - INFO - Stability 3399.0: Accuracy = 1.0
# 2024-09-24 14:11:30,345 - INFO - Stability 3400.0: Accuracy = 1.0
# 2024-09-24 14:11:30,345 - INFO - Stability 3400.5: Accuracy = 1.0
# 2024-09-24 14:11:30,347 - INFO - Stability 3402.5: Accuracy = 1.0
# 2024-09-24 14:11:30,347 - INFO - Stability 3404.0: Accuracy = 0.0
# 2024-09-24 14:11:30,348 - INFO - Stability 3404.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,350 - INFO - Stability 3406.5: Accuracy = 0.5
# 2024-09-24 14:11:30,351 - INFO - Stability 3407.5: Accuracy = 1.0
# 2024-09-24 14:11:30,352 - INFO - Stability 3408.5: Accuracy = 1.0
# 2024-09-24 14:11:30,353 - INFO - Stability 3411.5: Accuracy = 1.0
# 2024-09-24 14:11:30,354 - INFO - Stability 3413.5: Accuracy = 1.0
# 2024-09-24 14:11:30,355 - INFO - Stability 3420.0: Accuracy = 1.0
# 2024-09-24 14:11:30,356 - INFO - Stability 3423.0: Accuracy = 1.0
# 2024-09-24 14:11:30,357 - INFO - Stability 3424.5: Accuracy = 1.0
# 2024-09-24 14:11:30,358 - INFO - Stability 3433.0: Accuracy = 0.0
# 2024-09-24 14:11:30,359 - INFO - Stability 3435.5: Accuracy = 1.0
# 2024-09-24 14:11:30,360 - INFO - Stability 3436.5: Accuracy = 1.0
# 2024-09-24 14:11:30,361 - INFO - Stability 3437.0: Accuracy = 1.0
# 2024-09-24 14:11:30,361 - INFO - Stability 3439.5: Accuracy = 1.0
# 2024-09-24 14:11:30,362 - INFO - Stability 3442.0: Accuracy = 0.0
# 2024-09-24 14:11:30,364 - INFO - Stability 3443.0: Accuracy = 1.0
# 2024-09-24 14:11:30,365 - INFO - Stability 3446.0: Accuracy = 1.0
# 2024-09-24 14:11:30,366 - INFO - Stability 3448.0: Accuracy = 1.0
# 2024-09-24 14:11:30,367 - INFO - Stability 3450.5: Accuracy = 1.0
# 2024-09-24 14:11:30,368 - INFO - Stability 3457.5: Accuracy = 1.0
# 2024-09-24 14:11:30,370 - INFO - Stability 3462.5: Accuracy = 1.0
# 2024-09-24 14:11:30,371 - INFO - Stability 3464.0: Accuracy = 1.0
# 2024-09-24 14:11:30,372 - INFO - Stability 3468.0: Accuracy = 0.0
# 2024-09-24 14:11:30,373 - INFO - Stability 3470.0: Accuracy = 1.0
# 2024-09-24 14:11:30,374 - INFO - Stability 3473.0: Accuracy = 1.0
# 2024-09-24 14:11:30,375 - INFO - Stability 3475.0: Accuracy = 1.0
# 2024-09-24 14:11:30,377 - INFO - Stability 3475.5: Accuracy = 1.0
# 2024-09-24 14:11:30,378 - INFO - Stability 3476.0: Accuracy = 1.0
# 2024-09-24 14:11:30,379 - INFO - Stability 3479.5: Accuracy = 1.0
# 2024-09-24 14:11:30,380 - INFO - Stability 3481.5: Accuracy = 1.0
# 2024-09-24 14:11:30,381 - INFO - Stability 3482.5: Accuracy = 1.0
# 2024-09-24 14:11:30,382 - INFO - Stability 3483.5: Accuracy = 1.0
# 2024-09-24 14:11:30,383 - INFO - Stability 3488.0: Accuracy = 1.0
# 2024-09-24 14:11:30,384 - INFO - Stability 3488.5: Accuracy = 1.0
# 2024-09-24 14:11:30,385 - INFO - Stability 3489.5: Accuracy = 1.0
# 2024-09-24 14:11:30,386 - INFO - Stability 3490.5: Accuracy = 1.0
# 2024-09-24 14:11:30,386 - INFO - Stability 3491.5: Accuracy = 1.0
# 2024-09-24 14:11:30,387 - INFO - Stability 3494.0: Accuracy = 1.0
# 2024-09-24 14:11:30,388 - INFO - Stability 3495.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,390 - INFO - Stability 3499.0: Accuracy = 0.5
# 2024-09-24 14:11:30,391 - INFO - Stability 3500.0: Accuracy = 1.0
# 2024-09-24 14:11:30,391 - INFO - Stability 3505.5: Accuracy = 1.0
# 2024-09-24 14:11:30,392 - INFO - Stability 3507.0: Accuracy = 1.0
# 2024-09-24 14:11:30,393 - INFO - Stability 3511.5: Accuracy = 1.0
# 2024-09-24 14:11:30,394 - INFO - Stability 3512.5: Accuracy = 1.0
# 2024-09-24 14:11:30,394 - INFO - Stability 3513.0: Accuracy = 1.0
# 2024-09-24 14:11:30,395 - INFO - Stability 3516.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,397 - INFO - Stability 3517.0: Accuracy = 0.5
# 2024-09-24 14:11:30,398 - INFO - Stability 3520.5: Accuracy = 1.0
# 2024-09-24 14:11:30,399 - INFO - Stability 3524.0: Accuracy = 1.0
# 2024-09-24 14:11:30,399 - INFO - Stability 3528.5: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,401 - INFO - Stability 3530.0: Accuracy = 0.6666666666666666
# 2024-09-24 14:11:30,402 - INFO - Stability 3531.0: Accuracy = 1.0
# 2024-09-24 14:11:30,404 - INFO - Stability 3535.0: Accuracy = 1.0
# 2024-09-24 14:11:30,406 - INFO - Stability 3535.5: Accuracy = 1.0
# 2024-09-24 14:11:30,407 - INFO - Stability 3538.0: Accuracy = 1.0
# 2024-09-24 14:11:30,408 - INFO - Stability 3540.0: Accuracy = 1.0
# 2024-09-24 14:11:30,410 - INFO - Stability 3540.5: Accuracy = 1.0
# 2024-09-24 14:11:30,411 - INFO - Stability 3544.5: Accuracy = 1.0
# 2024-09-24 14:11:30,412 - INFO - Stability 3546.5: Accuracy = 1.0
# 2024-09-24 14:11:30,414 - INFO - Stability 3552.0: Accuracy = 1.0
# 2024-09-24 14:11:30,416 - INFO - Stability 3555.0: Accuracy = 1.0
# 2024-09-24 14:11:30,417 - INFO - Stability 3557.0: Accuracy = 1.0
# 2024-09-24 14:11:30,418 - INFO - Stability 3557.5: Accuracy = 1.0
# 2024-09-24 14:11:30,419 - INFO - Stability 3558.5: Accuracy = 1.0
# 2024-09-24 14:11:30,420 - INFO - Stability 3559.0: Accuracy = 1.0
# 2024-09-24 14:11:30,421 - INFO - Stability 3560.0: Accuracy = 1.0
# 2024-09-24 14:11:30,423 - INFO - Stability 3564.5: Accuracy = 0.0
# 2024-09-24 14:11:30,423 - INFO - Stability 3566.5: Accuracy = 1.0
# 2024-09-24 14:11:30,424 - INFO - Stability 3573.5: Accuracy = 1.0
# 2024-09-24 14:11:30,425 - INFO - Stability 3574.0: Accuracy = 1.0
# 2024-09-24 14:11:30,427 - INFO - Stability 3575.5: Accuracy = 1.0
# 2024-09-24 14:11:30,428 - INFO - Stability 3578.0: Accuracy = 1.0
# /home/itayab/.conda/envs/itay_geometric/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 2024-09-24 14:11:30,430 - INFO - Stability 3580.0: Accuracy = 0.5
# 2024-09-24 14:11:30,432 - INFO - Stability 3580.5: Accuracy = 0.5
# 2024-09-24 14:11:30,435 - INFO - Stability 3581.0: Accuracy = 1.0
# 2024-09-24 14:11:30,436 - INFO - Stability 3583.0: Accuracy = 1.0
# 2024-09-24 14:11:30,437 - INFO - Stability 3583.5: Accuracy = 1.0
# 2024-09-24 14:11:30,437 - INFO - Stability 3585.0: Accuracy = 1.0
# 2024-09-24 14:11:30,439 - INFO - Stability 3586.0: Accuracy = 1.0
# 2024-09-24 14:11:30,439 - INFO - Stability 3586.5: Accuracy = 1.0
# 2024-09-24 14:11:30,441 - INFO - Stability 3587.0: Accuracy = 1.0
# 2024-09-24 14:11:30,442 - INFO - Stability 3587.5: Accuracy = 0.0
# 2024-09-24 14:11:30,443 - INFO - Stability 3589.5: Accuracy = 1.0
# 2024-09-24 14:11:30,443 - INFO - Stability 3590.5: Accuracy = 1.0
# 2024-09-24 14:11:30,444 - INFO - Stability 3592.0: Accuracy = 1.0
# 2024-09-24 14:11:30,445 - INFO - Stability 3593.5: Accuracy = 1.0
# 2024-09-24 14:11:30,448 - INFO - Stability 3595.0: Accuracy = 1.0
# 2024-09-24 14:11:30,449 - INFO - Stability 3596.5: Accuracy = 1.0
# 2024-09-24 14:11:30,450 - INFO - Stability 3597.0: Accuracy = 1.0
# 2024-09-24 14:11:30,453 - INFO - Stability 3600.5: Accuracy = 1.0
# 2024-09-24 14:11:30,454 - INFO - Stability 3601.5: Accuracy = 0.0

# %% [markdown]
# # 6. Step 5: Calibrate the Test Data
# After fitting the calibrator, use it to predict and calibrate the probabilities for the test set.

# %%
# Calibrate the predictions on the test set using FAISS-based calibrator
calibrated_probs_faiss = geo_calibrator_faiss.calibrate(X_test)

# Get predicted labels by selecting the class with the highest calibrated probability for FAISS
y_test_pred_faiss = np.argmax(calibrated_probs_faiss, axis=1)

# Calculate accuracy for FAISS
accuracy_faiss = accuracy_score(y_test, y_test_pred_faiss)
print(f"Accuracy after calibration with FAISS: {accuracy_faiss}")

# # Calibrate the predictions on the test set using KNN-based calibrator
# calibrated_probs_knn = geo_calibrator_knn.calibrate(X_test)

# # Get predicted labels by selecting the class with the highest calibrated probability for KNN
# y_test_pred_knn = np.argmax(calibrated_probs_knn, axis=1)

# # Calculate accuracy for KNN
# accuracy_knn = accuracy_score(y_test, y_test_pred_knn)
# print(f"Accuracy after calibration with KNN: {accuracy_knn}")
# Out:
# 2024-09-23 19:09:05,958 - INFO - GeometricCalibrator: Calibrating test data.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# 2024-09-23 19:09:09,012 - INFO - Starting calibration for 14000 samples and 10 classes.
# 2024-09-23 19:09:09,013 - INFO - Calculating stability using faiss with metric l2.
# 2024-09-23 19:09:09,014 - INFO - Starting stability calculation using faiss with metric: l2.
# Running without compression, the shape of X needs to be square
# Calculating Stability: 100%|██████████| 14000/14000 [03:07<00:00, 74.57sample/s]
# 2024-09-23 19:12:16,754 - INFO - Completed stability calculation.
# 2024-09-23 19:12:16,756 - INFO - Stability values during calibration (first 10): [12427.5  9949.5  5789.    206.  -1659.5 16998.   3926.5  9906.   9403.
#  -1217. ]
# 2024-09-23 19:12:16,759 - INFO - Calibrated values (first 10): [0.11476546 0.11476546 0.11442429 0.11442429 0.104      0.11515334
#  0.11442429 0.11476546 0.11476546 0.10757576]
# 2024-09-23 19:12:16,813 - INFO - GeometricCalibrator: Calibration successful.
# Accuracy after calibration with FAISS: 0.9390714285714286

# %% [markdown]
# # 7. Step 6: Calculate ECE
# Evaluate the calibration by computing the Expected Calibration Error (ECE).

# %%
import logging

logger = logging.getLogger(__name__)
def ECE_calc(probs, y_pred, y_real, n_bins=20):
    """
    Expected Calibration Error (ECE) calculation.

    Parameters:
        probs (np.ndarray): Calibrated probabilities for each class.
        y_pred (np.ndarray): Predicted class labels.
        y_real (np.ndarray): True class labels.
        n_bins (int): Number of bins to divide probabilities.

    Returns:
        float: ECE value.
    """
    logger.info("Starting Expected Calibration Error (ECE) calculation.")

    # Select the probabilities of the predicted classes
    confidence_of_pred_class = np.max(probs, axis=1)

    # Bin the confidences
    bin_boundaries = np.linspace(0, 1, n_bins + 1)
    bin_indices = np.digitize(confidence_of_pred_class, bin_boundaries) - 1

    logger.info(f"Bin boundaries: {bin_boundaries}")
    logger.info(f"Bin indices (first 10): {bin_indices[:10]}")
    
    total_error = 0.0
    total_weight = 0.0  # To track the weight distribution

    for i in range(n_bins):
        bin_mask = bin_indices == i
        bin_confidences = confidence_of_pred_class[bin_mask]
        bin_real = y_real[bin_mask]
        bin_pred = y_pred[bin_mask]

        if len(bin_confidences) > 0:
            bin_acc = np.mean(bin_real == bin_pred)
            bin_conf = np.mean(bin_confidences)
            bin_weight = len(bin_confidences) / len(probs)
            total_error += bin_weight * np.abs(bin_acc - bin_conf)
            total_weight += bin_weight

            logger.info(f"Bin {i}:")
            logger.info(f"  Bin size: {len(bin_confidences)}")
            logger.info(f"  Accuracy: {bin_acc}")
            logger.info(f"  Confidence: {bin_conf}")
            logger.info(f"  Bin weight: {bin_weight}")
            logger.info(f"  ECE contribution: {bin_weight * np.abs(bin_acc - bin_conf)}")
        else:
            logger.info(f"Bin {i} is empty.")

    logger.info(f"Total weight: {total_weight}")
    logger.info(f"Final ECE value: {total_error}")
    
    return total_error
# Predict on the test data using the trained model (without calibration)
y_test_pred_raw = cnn_model.predict(X_test)  # This is the predicted probabilities
y_test_pred_labels_raw = np.argmax(y_test_pred_raw, axis=1)  # This is the predicted class labels

# Calculate ECE for the model without calibration (raw probabilities)
ece_value_raw = ECE_calc(y_test_pred_raw, y_test_pred_labels_raw, y_test)  # Pass raw probabilities and labels
print(f"ECE without calibration: {ece_value_raw}")

# Calculate ECE for FAISS-based calibrated probabilities
ece_value_faiss = ECE_calc(calibrated_probs_faiss, y_test_pred_faiss, y_test)  # Pass calibrated probabilities and labels
print(f"ECE after FAISS calibration: {ece_value_faiss}")

print(f"For debug purpose, raw probs: {y_test_pred_raw} calibrated probs: {calibrated_probs_faiss}")
# # Calculate ECE for KNN-based calibrated probabilities
# ece_value_knn = ECE_calc(y_test_pred_knn, calibrated_probs_knn, y_test)
# print(f"ECE after KNN calibration: {ece_value_knn}")
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 2024-09-23 19:12:19,581 - INFO - Starting Expected Calibration Error (ECE) calculation.
# 2024-09-23 19:12:19,584 - INFO - Bin boundaries: [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]
# 2024-09-23 19:12:19,584 - INFO - Bin indices (first 10): [19 19 19 19 19 19 19 19 19 19]
# 2024-09-23 19:12:19,585 - INFO - Bin 0 is empty.
# 2024-09-23 19:12:19,587 - INFO - Bin 1 is empty.
# 2024-09-23 19:12:19,588 - INFO - Bin 2 is empty.
# 2024-09-23 19:12:19,589 - INFO - Bin 3 is empty.
# 2024-09-23 19:12:19,589 - INFO - Bin 4 is empty.
# 2024-09-23 19:12:19,591 - INFO - Bin 5:
# 2024-09-23 19:12:19,591 - INFO -   Bin size: 1
# 2024-09-23 19:12:19,592 - INFO -   Accuracy: 1.0
# 2024-09-23 19:12:19,593 - INFO -   Confidence: 0.29476022720336914
# 2024-09-23 19:12:19,594 - INFO -   Bin weight: 7.142857142857143e-05
# 2024-09-23 19:12:19,594 - INFO -   ECE contribution: 5.037426948547364e-05
# 2024-09-23 19:12:19,596 - INFO - Bin 6:
# 2024-09-23 19:12:19,597 - INFO -   Bin size: 5
# 2024-09-23 19:12:19,597 - INFO -   Accuracy: 0.0
# 2024-09-23 19:12:19,598 - INFO -   Confidence: 0.3346732258796692
# 2024-09-23 19:12:19,599 - INFO -   Bin weight: 0.00035714285714285714
# 2024-09-23 19:12:19,600 - INFO -   ECE contribution: 0.00011952615209988185
# 2024-09-23 19:12:19,601 - INFO - Bin 7:
# 2024-09-23 19:12:19,602 - INFO -   Bin size: 12
# 2024-09-23 19:12:19,603 - INFO -   Accuracy: 0.4166666666666667
# 2024-09-23 19:12:19,603 - INFO -   Confidence: 0.36668917536735535
# 2024-09-23 19:12:19,604 - INFO -   Bin weight: 0.0008571428571428571
# 2024-09-23 19:12:19,605 - INFO -   ECE contribution: 4.2837849685124e-05
# 2024-09-23 19:12:19,607 - INFO - Bin 8:
# 2024-09-23 19:12:19,607 - INFO -   Bin size: 25
# 2024-09-23 19:12:19,608 - INFO -   Accuracy: 0.44
# 2024-09-23 19:12:19,609 - INFO -   Confidence: 0.42501720786094666
# 2024-09-23 19:12:19,609 - INFO -   Bin weight: 0.0017857142857142857
# 2024-09-23 19:12:19,610 - INFO -   ECE contribution: 2.675498596259526e-05
# 2024-09-23 19:12:19,612 - INFO - Bin 9:
# 2024-09-23 19:12:19,613 - INFO -   Bin size: 35
# 2024-09-23 19:12:19,613 - INFO -   Accuracy: 0.3142857142857143
# 2024-09-23 19:12:19,614 - INFO -   Confidence: 0.48004084825515747
# 2024-09-23 19:12:19,615 - INFO -   Bin weight: 0.0025
# 2024-09-23 19:12:19,615 - INFO -   ECE contribution: 0.000414387834923608
# 2024-09-23 19:12:19,617 - INFO - Bin 10:
# 2024-09-23 19:12:19,618 - INFO -   Bin size: 92
# 2024-09-23 19:12:19,619 - INFO -   Accuracy: 0.42391304347826086
# 2024-09-23 19:12:19,619 - INFO -   Confidence: 0.5212911367416382
# 2024-09-23 19:12:19,620 - INFO -   Bin weight: 0.006571428571428572
# 2024-09-23 19:12:19,621 - INFO -   ECE contribution: 0.0006399131843021938
# 2024-09-23 19:12:19,622 - INFO - Bin 11:
# 2024-09-23 19:12:19,623 - INFO -   Bin size: 83
# 2024-09-23 19:12:19,624 - INFO -   Accuracy: 0.40963855421686746
# 2024-09-23 19:12:19,624 - INFO -   Confidence: 0.5733277797698975
# 2024-09-23 19:12:19,625 - INFO -   Bin weight: 0.005928571428571429
# 2024-09-23 19:12:19,626 - INFO -   ECE contribution: 0.0009704432657786779
# 2024-09-23 19:12:19,628 - INFO - Bin 12:
# 2024-09-23 19:12:19,629 - INFO -   Bin size: 85
# 2024-09-23 19:12:19,629 - INFO -   Accuracy: 0.4588235294117647
# 2024-09-23 19:12:19,630 - INFO -   Confidence: 0.626477837562561
# 2024-09-23 19:12:19,631 - INFO -   Bin weight: 0.006071428571428571
# 2024-09-23 19:12:19,632 - INFO -   ECE contribution: 0.001017901156629835
# 2024-09-23 19:12:19,634 - INFO - Bin 13:
# 2024-09-23 19:12:19,635 - INFO -   Bin size: 87
# 2024-09-23 19:12:19,636 - INFO -   Accuracy: 0.5632183908045977
# 2024-09-23 19:12:19,637 - INFO -   Confidence: 0.6761354804039001
# 2024-09-23 19:12:19,638 - INFO -   Bin weight: 0.006214285714285714
# 2024-09-23 19:12:19,639 - INFO -   ECE contribution: 0.0007016990567956652
# 2024-09-23 19:12:19,642 - INFO - Bin 14:
# 2024-09-23 19:12:19,642 - INFO -   Bin size: 109
# 2024-09-23 19:12:19,643 - INFO -   Accuracy: 0.6055045871559633
# 2024-09-23 19:12:19,644 - INFO -   Confidence: 0.7259066104888916
# 2024-09-23 19:12:19,645 - INFO -   Bin weight: 0.007785714285714286
# 2024-09-23 19:12:19,646 - INFO -   ECE contribution: 0.0009374157530920843
# 2024-09-23 19:12:19,649 - INFO - Bin 15:
# 2024-09-23 19:12:19,649 - INFO -   Bin size: 97
# 2024-09-23 19:12:19,650 - INFO -   Accuracy: 0.5670103092783505
# 2024-09-23 19:12:19,651 - INFO -   Confidence: 0.7754432559013367
# 2024-09-23 19:12:19,652 - INFO -   Bin weight: 0.006928571428571429
# 2024-09-23 19:12:19,653 - INFO -   ECE contribution: 0.0014441425587449757
# 2024-09-23 19:12:19,656 - INFO - Bin 16:
# 2024-09-23 19:12:19,657 - INFO -   Bin size: 133
# 2024-09-23 19:12:19,658 - INFO -   Accuracy: 0.6090225563909775
# 2024-09-23 19:12:19,659 - INFO -   Confidence: 0.827838659286499
# 2024-09-23 19:12:19,660 - INFO -   Bin weight: 0.0095
# 2024-09-23 19:12:19,661 - INFO -   ECE contribution: 0.002078752977507455
# 2024-09-23 19:12:19,663 - INFO - Bin 17:
# 2024-09-23 19:12:19,664 - INFO -   Bin size: 180
# 2024-09-23 19:12:19,665 - INFO -   Accuracy: 0.7111111111111111
# 2024-09-23 19:12:19,666 - INFO -   Confidence: 0.8768692016601562
# 2024-09-23 19:12:19,667 - INFO -   Bin weight: 0.012857142857142857
# 2024-09-23 19:12:19,668 - INFO -   ECE contribution: 0.0021311754499162942
# 2024-09-23 19:12:19,670 - INFO - Bin 18:
# 2024-09-23 19:12:19,671 - INFO -   Bin size: 276
# 2024-09-23 19:12:19,672 - INFO -   Accuracy: 0.6376811594202898
# 2024-09-23 19:12:19,673 - INFO -   Confidence: 0.928034245967865
# 2024-09-23 19:12:19,674 - INFO -   Bin weight: 0.019714285714285715
# 2024-09-23 19:12:19,674 - INFO -   ECE contribution: 0.005724103706223626
# 2024-09-23 19:12:19,677 - INFO - Bin 19:
# 2024-09-23 19:12:19,678 - INFO -   Bin size: 12780
# 2024-09-23 19:12:19,679 - INFO -   Accuracy: 0.9743348982785602
# 2024-09-23 19:12:19,680 - INFO -   Confidence: 0.998407244682312
# 2024-09-23 19:12:19,681 - INFO -   Bin weight: 0.9128571428571428
# 2024-09-23 19:12:19,682 - INFO -   ECE contribution: 0.021974613359996262
# 2024-09-23 19:12:19,683 - INFO - Total weight: 1.0
# 2024-09-23 19:12:19,684 - INFO - Final ECE value: 0.03827404156114375
# 2024-09-23 19:12:19,685 - INFO - Starting Expected Calibration Error (ECE) calculation.
# 2024-09-23 19:12:19,690 - INFO - Bin boundaries: [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]
# 2024-09-23 19:12:19,691 - INFO - Bin indices (first 10): [2 2 2 2 2 2 2 2 2 2]
# 2024-09-23 19:12:19,692 - INFO - Bin 0 is empty.
# 2024-09-23 19:12:19,693 - INFO - Bin 1 is empty.
# 2024-09-23 19:12:19,694 - INFO - Bin 2:
# 2024-09-23 19:12:19,695 - INFO -   Bin size: 14000
# 2024-09-23 19:12:19,696 - INFO -   Accuracy: 0.9390714285714286
# 2024-09-23 19:12:19,696 - INFO -   Confidence: 0.11444392304838423
# 2024-09-23 19:12:19,697 - INFO -   Bin weight: 1.0
# 2024-09-23 19:12:19,698 - INFO -   ECE contribution: 0.8246275055230443
# 2024-09-23 19:12:19,699 - INFO - Bin 3 is empty.
# 2024-09-23 19:12:19,702 - INFO - Bin 4 is empty.
# 2024-09-23 19:12:19,703 - INFO - Bin 5 is empty.
# 2024-09-23 19:12:19,704 - INFO - Bin 6 is empty.
# 2024-09-23 19:12:19,706 - INFO - Bin 7 is empty.
# 2024-09-23 19:12:19,706 - INFO - Bin 8 is empty.
# 2024-09-23 19:12:19,707 - INFO - Bin 9 is empty.
# 2024-09-23 19:12:19,708 - INFO - Bin 10 is empty.
# 2024-09-23 19:12:19,709 - INFO - Bin 11 is empty.
# 2024-09-23 19:12:19,710 - INFO - Bin 12 is empty.
# 2024-09-23 19:12:19,711 - INFO - Bin 13 is empty.
# 2024-09-23 19:12:19,712 - INFO - Bin 14 is empty.
# 2024-09-23 19:12:19,713 - INFO - Bin 15 is empty.
# 2024-09-23 19:12:19,714 - INFO - Bin 16 is empty.
# 2024-09-23 19:12:19,715 - INFO - Bin 17 is empty.
# 2024-09-23 19:12:19,715 - INFO - Bin 18 is empty.
# 2024-09-23 19:12:19,717 - INFO - Bin 19 is empty.
# 2024-09-23 19:12:19,717 - INFO - Total weight: 1.0
# 2024-09-23 19:12:19,718 - INFO - Final ECE value: 0.8246275055230443
# ECE without calibration: 0.03827404156114375
# ECE after FAISS calibration: 0.8246275055230443
# For debug purpose, raw probs: [[9.99999940e-01 5.24300392e-15 1.04556974e-10 ... 3.71166476e-13
#   5.11456121e-11 2.98514269e-10]
#  [5.04472283e-16 3.51001847e-14 6.73396777e-13 ... 4.49320581e-09
#   3.75413727e-08 3.08899240e-09]
#  [2.44305959e-19 9.99999940e-01 2.11173073e-17 ... 1.20417158e-13
#   5.66953626e-15 1.77918609e-16]
#  ...
#  [1.12077350e-06 5.98498627e-06 8.02869454e-06 ... 9.99950349e-01
#   2.81106995e-08 1.42379859e-08]
#  [5.48741655e-15 7.35618814e-13 2.69353533e-11 ... 3.35309460e-06
#   2.00430563e-07 3.11651771e-09]
#  [6.10045001e-12 3.77386803e-18 1.26491837e-16 ... 2.14303473e-21
#   1.97911479e-11 4.51686106e-13]] calibrated probs: [[0.11476546 0.09835939 0.09835939 ... 0.09835939 0.09835939 0.09835939]
#  [0.09835939 0.09835939 0.09835939 ... 0.09835939 0.09835939 0.09835939]
#  [0.0983973  0.11442429 0.0983973  ... 0.0983973  0.0983973  0.0983973 ]
#  ...
#  [0.0983973  0.0983973  0.0983973  ... 0.11442429 0.0983973  0.0983973 ]
#  [0.0983973  0.0983973  0.0983973  ... 0.0983973  0.0983973  0.0983973 ]
#  [0.09835939 0.09835939 0.09835939 ... 0.09835939 0.09835939 0.09835939]]

# %% [markdown]
# # 8. Step 7: Run Multiple Experiments
# Wrap the entire pipeline in a loop to test different augmentation methods and repeat the experiment multiple times.

# %%
augmentation_methods = ['rotation', 'shift', 'noise']
results = {}

for method in augmentation_methods:
    print(f"Running experiment with {method} augmentation...")
    augmented_train_images = augment_data(X_train, method=method)
    
    # Train the CNN model
    cnn_model.fit(augmented_train_images, y_train, epochs=10)
    features_val = cnn_model.predict(X_val)
    features_test = cnn_model.predict(X_test)
    
    # Initialize and fit the geometric calibrator
    geo_calibrator = GeometricCalibrator(model=cnn_model, X_train=features_val, y_train=y_val)
    geo_calibrator.fit(X_val, y_val)
    
    # Calibrate the test set
    calibrated_probs = geo_calibrator.calibrate(X_test)
    y_test_pred = np.argmax(calibrated_probs, axis=1)
    
    # Calculate ECE
    ece_value = ECE_calc(y_test_pred, calibrated_probs, y_test)
    results[method] = ece_value
    print(f"{method} ECE: {ece_value}")

# Find the best augmentation method based on ECE
best_method = min(results, key=results.get)
print(f"Best augmentation method: {best_method} with ECE = {results[best_method]}")
